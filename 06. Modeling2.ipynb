# %% [markdown]
# # Python TFM Section

# %% [markdown]
# ## Modelling
# 1. Compare several models and use the most suitable for this case of study
# 2. Train and Test the final model and set it up implemented
# 3. Final conclusions

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
plt.style.use('ggplot')
from pathlib import Path
import sklearn
from scipy import stats
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# df_modelize = pd.read_csv(Path.cwd() / 'Outputs' / 'DF_MODELIZE.csv', sep = ';', header = 0 , encoding = "ISO-8859-1",decimal=',')
df_modelize = pd.read_csv(Path.cwd() / 'DF_MODELIZE.csv', sep = ';', header = 0 , encoding = "ISO-8859-1",decimal=',')
df_modelize.head(5)
# Out:
#    VERSION   ID_UPR ID_TECNOLOGIA  A. No Cobrados  AMONIACO  ATR    Ajuste  \
# 0   201701   UPR115            NC             NaN       NaN  NaN       NaN
# 1   201701   UPR116            NC             NaN       NaN  NaN       NaN
# 2   201701  UPR1198            NC             NaN       NaN  NaN       NaN
# 3   201701  UPR1205            EB             NaN       NaN  NaN -124366.0
# 4   201701  UPR1206            BX             NaN       NaN  NaN   -9972.0
#
#    BONO_SOCIAL_PEGO  Banda   Bilateral  ...  Res. Pot. Adicional  \
# 0               NaN    NaN  81778497.0  ...                  NaN
# 1               NaN    NaN  68455391.0  ...                  NaN
# 2               NaN    NaN         NaN  ...                  NaN
# 3               NaN    NaN   1578792.0  ...                  NaN
# 4               NaN    NaN         NaN  ...                  NaN
#
#    S. Regulacion  S. Res. Pot. Adicional  SERV_GEST_RES  TASAS_MEDIOAMB  \
# 0            NaN                   -36.0     -5156083.0             NaN
# 1            NaN                     NaN     -4357224.0             NaN
# 2            NaN                  -192.0            NaN             NaN
# 3            NaN                  -455.0            NaN        -33711.0
# 4            NaN                    -7.0            NaN        -16346.0
#
#    TASA_ARAGON  Terciaria  UREA  VCF    POWER_MWH
# 0          NaN        NaN   NaN  NaN  1111803.766
# 1          NaN        NaN   NaN  NaN   940091.558
# 2          NaN        NaN   NaN  NaN    -1418.032
# 3          NaN    55144.0   NaN  NaN    22830.702
# 4          NaN        NaN   NaN  NaN     -418.593
#
# [5 rows x 46 columns]

# %% [markdown]
# Before aplying any model:
#
# 1. All NaNs are now filled with 0s
# 2. I will create a synthetic column named INTEGRAL_COSTS summing every single cost column
# 3. Let's drop all the outliers and negative values
# 4. I filter by the technologie, dropping technologies 3 and 4 for being Bx and Bp
# 3. I will inspect the graphical aspect of the data INTEGRAL_COSTS vs POWER_MWH

# %%
df_modelize = df_modelize.fillna(0)

df_modelize['INTEGRAL_COSTS']  = \
df_modelize['AMONIACO'] + \
df_modelize['ATR'] + \
df_modelize['BONO_SOCIAL_PEGO'] + \
df_modelize['CALIZAS'] + \
df_modelize['CANON HID'] + \
df_modelize['CANON_CONCESION'] + \
df_modelize['CANON_HID_CATALUÃÂA'] + \
df_modelize['CANON_NC_CATALUÃÂA'] + \
df_modelize['CANON_NC_EST'] + \
df_modelize['CENTIMO_VERDE'] + \
df_modelize['COSTE_COMBUSTIBLE'] + \
df_modelize['IMPUESTO ELECT'] + \
df_modelize['LUBRICANTES'] + \
df_modelize['OTROS'] + \
df_modelize['PEAJE GEN'] +  \
df_modelize['RELIQ_CANON_NC_CATALUÃÂA'] +  \
df_modelize['SERV_GEST_RES'] + \
df_modelize['TASAS_MEDIOAMB'] + \
df_modelize['TASA_ARAGON'] 



df_modelize2 = df_modelize[['VERSION','ID_TECNOLOGIA','POWER_MWH','INTEGRAL_COSTS']]
df_tech= df_modelize2[['ID_TECNOLOGIA']].drop_duplicates()
df_tech['NUM_TECH']= [1,2,3,4,5,6,7,8]
df_tech.reset_index
df_modelize2 = pd.merge(df_modelize2, df_tech, on=['ID_TECNOLOGIA'], how='left')
# df_modelize5['UNITARY_COST'] = df_modelize4['INTEGRAL_COSTS'] / df_modelize4['POWER_MWH']
df_modelize2 = df_modelize2[['VERSION','POWER_MWH','INTEGRAL_COSTS','NUM_TECH']]


df_modelize2= df_modelize2[(np.abs(stats.zscore(df_modelize2)) < 2).all(axis=1)].reset_index()
df_modelize2 = df_modelize2[['VERSION','POWER_MWH','INTEGRAL_COSTS','NUM_TECH']]
df_modelize2 = df_modelize2[(df_modelize2['POWER_MWH']>0)]
df_modelize2 = df_modelize2[(df_modelize2['INTEGRAL_COSTS']<0)]
df_modelize2 = df_modelize2[df_modelize2['NUM_TECH'] != 3]
df_modelize2 = df_modelize2[df_modelize2['NUM_TECH'] != 4]

plt.show(figsize(30,10))
plt.scatter(df_modelize2['INTEGRAL_COSTS'],df_modelize2['POWER_MWH'],c=df_modelize2['NUM_TECH'])

# %% [markdown]
# Here we can see the aspect of costs vs power for each technology remaining during the time

# %%
import numpy as np
import matplotlib.pyplot as plt

df_temp == df_modelize2
df_temp['VERSION'] = pd.to_datetime(df_temp['VERSION'], format='%Y%m', errors='coerce').dropna()
#
tech = 6

plt.show(figsize(30,10))
plt.scatter(df_temp[df_temp['NUM_TECH'] == tech]['VERSION'], df_temp[df_temp['NUM_TECH'] == tech]['INTEGRAL_COSTS'])
plt.scatter(df_temp[df_temp['NUM_TECH'] == tech]['VERSION'], df_temp[df_temp['NUM_TECH'] == tech]['POWER_MWH'])
print(df_tech)
# Out:
#    ID_TECNOLOGIA  NUM_TECH
# 0             NC         1
# 3             EB         2
# 4             BX         3
# 6             BP         4
# 8             GN         5
# 10            CI         6
# 21            HN         7
# 27            LN         8

# %%
df_modelize5=df_modelize2

# %%
df_modelize5.head(10)
# Out:
#     VERSION   POWER_MWH  INTEGRAL_COSTS  NUM_TECH
# 0    201701  940091.558     -11215426.0         1
# 2    201701   22830.702       -242300.0         2
# 4    201701   11909.436       -105460.0         2
# 7    201701   84359.878      -4035043.0         5
# 8    201701  109060.598      -2625416.0         5
# 10   201701  474587.897      -6829530.0         6
# 13   201701  216999.300      -2462798.0         5
# 14   201701  186060.200      -2747524.0         5
# 15   201701  347537.922      -4629991.0         6
# 16   201701  343653.366      -4500749.0         6

# %% [markdown]
# # Model Aplication

# %% [markdown]
# First, I proceed to separate the data frame into Train-Test parts
#
# For that, I divide the original df into two parts with the inputs on the matrix X and the  outputs desired on the matrix y
# and the metric used for the evaluation at first will be MAE

# %% [markdown]
# ## Instances Creation

# %%
# Import Library
from sklearn.model_selection import train_test_split

X = df_modelize5[['VERSION','NUM_TECH','POWER_MWH']]
y = df_modelize5['INTEGRAL_COSTS']


# Create Instance
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.10 , random_state = 42)

# %% [markdown]
# ## First aproach: Linear Regressor

# %%
# Load the library
from sklearn.linear_model import LinearRegression
# Create an instance of the model
regL = LinearRegression()
# Fit the regressor
regL.fit(X_train,y_train)
# Do predictions
y_regL_pred = regL.predict(X_test)

# %% [markdown]
# Let's check the mean absolute error as well as the distribution of the diferences between the test and the predictions

# %%
print(np.mean(np.abs(y_test-y_regL_pred)))
print("Mean error represents ", round(100*np.mean(np.abs(y_test-y_regL_pred))/df_modelize5['INTEGRAL_COSTS'].mean()), "% from the mean value")
plt.hist(y_test-y_regL_pred,bins=50);
# Out:
# 1753703.436361595
# Mean error represents  -47 % from the mean value

# %% [markdown]
# ## Second Aproach: KNeighbors

# %%
# Load the library
from sklearn.neighbors import KNeighborsRegressor
# Create an instance
regKN = KNeighborsRegressor(n_neighbors=15)
# Fit the data
regKN.fit(X_train,y_train)
# Do predictions
y_regKN_pred = regKN.predict(X_test)

# %%
print(np.mean(np.abs(y_test-y_regKN_pred)))
print("Mean error represents ", round(100*np.mean(np.abs(y_test-y_regKN_pred))/df_modelize5['INTEGRAL_COSTS'].mean()), "% from the mean value")
plt.hist(y_test-y_regKN_pred,bins=50);
# Out:
# 1750167.6022222224
# Mean error represents  -47 % from the mean value

# %% [markdown]
# Now, I will apply a GridSearchCV to see how this could be improved

# %%
# Import Library
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor

# Create instance
regGsCvKN = GridSearchCV(KNeighborsRegressor(),
                  param_grid = {"n_neighbors":np.arange(3,50)},
                  cv=5,
                  scoring="neg_mean_absolute_error",
                  verbose=9)
                     
                      
# Fit will test all of the combinations
regGsCvKN.fit(X,y)


print(regGsCvKN.best_params_)
print(regGsCvKN.best_score_)
# Out:
# Fitting 5 folds for each of 47 candidates, totalling 235 fits
# [CV] n_neighbors=3 ...................................................
# [CV] ......... n_neighbors=3, score=-1983097.2072829132, total=   0.0s
# [CV] n_neighbors=3 ...................................................
# [CV] .......... n_neighbors=3, score=-1768296.512605042, total=   0.0s
# [CV] n_neighbors=3 ...................................................
# [CV] ......... n_neighbors=3, score=-2109317.0677966103, total=   0.0s
# [CV] n_neighbors=3 ...................................................
# [CV] ......... n_neighbors=3, score=-1959962.1694915255, total=   0.0s
# [CV] n_neighbors=3 ...................................................
# [CV] ......... n_neighbors=3, score=-1780023.0762711861, total=   0.0s
# [CV] n_neighbors=4 ...................................................
# [CV] ......... n_neighbors=4, score=-1985433.3991596638, total=   0.0s
# [CV] n_neighbors=4 ...................................................
# [CV] ......... n_neighbors=4, score=-1676054.3781512605, total=   0.0s
# [CV] n_neighbors=4 ...................................................
# [CV] ......... n_neighbors=4, score=-2026721.6461864407, total=   0.0s
# [CV] n_neighbors=4 ...................................................
# [CV] ......... n_neighbors=4, score=-1896891.8580508474, total=   0.0s
# [CV] n_neighbors=4 ...................................................
# [CV] ......... n_neighbors=4, score=-1820329.8919491526, total=   0.0s
# [CV] n_neighbors=5 ...................................................
# [CV] .......... n_neighbors=5, score=-1978037.329411765, total=   0.0s
# [CV] n_neighbors=5 ...................................................
# [CV] ......... n_neighbors=5, score=-1633124.4252100838, total=   0.0s
# [CV] n_neighbors=5 ...................................................
# [CV] ......... n_neighbors=5, score=-1988114.2491525428, total=   0.0s
# [CV] n_neighbors=5 ...................................................
# [CV] ......... n_neighbors=5, score=-1955883.6898305083, total=   0.0s
# [CV] n_neighbors=5 ...................................................
# [CV] .......... n_neighbors=5, score=-1810709.905084746, total=   0.0s
# [CV] n_neighbors=6 ...................................................
# [CV] .......... n_neighbors=6, score=-1979792.091036415, total=   0.0s
# [CV] n_neighbors=6 ...................................................
# [CV] ......... n_neighbors=6, score=-1587844.0812324935, total=   0.0s
# [CV] n_neighbors=6 ...................................................
# [CV] ......... n_neighbors=6, score=-1954465.7584745765, total=   0.0s
# [CV] n_neighbors=6 ...................................................
# [CV] ......... n_neighbors=6, score=-1905443.0974576268, total=   0.0s
# [CV] n_neighbors=6 ...................................................
# [CV] .......... n_neighbors=6, score=-1807754.540960452, total=   0.0s
# [CV] n_neighbors=7 ...................................................
# [CV] .......... n_neighbors=7, score=-1994346.480192077, total=   0.0s
# [CV] n_neighbors=7 ...................................................
# [CV] ......... n_neighbors=7, score=-1580149.7394957982, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s remaining:    0.0s
# [CV] n_neighbors=7 ...................................................
# [CV] ......... n_neighbors=7, score=-1946075.1743341405, total=   0.0s
# [CV] n_neighbors=7 ...................................................
# [CV] ......... n_neighbors=7, score=-1832057.8026634385, total=   0.0s
# [CV] n_neighbors=7 ...................................................
# [CV] ......... n_neighbors=7, score=-1775703.7687651336, total=   0.0s
# [CV] n_neighbors=8 ...................................................
# [CV] ......... n_neighbors=8, score=-1998285.5682773108, total=   0.0s
# [CV] n_neighbors=8 ...................................................
# [CV] ......... n_neighbors=8, score=-1548824.5976890756, total=   0.0s
# [CV] n_neighbors=8 ...................................................
# [CV] ................ n_neighbors=8, score=-1910350.125, total=   0.0s
# [CV] n_neighbors=8 ...................................................
# [CV] ......... n_neighbors=8, score=-1888958.3199152541, total=   0.0s
# [CV] n_neighbors=8 ...................................................
# [CV] .......... n_neighbors=8, score=-1772504.402542373, total=   0.0s
# [CV] n_neighbors=9 ...................................................
# [CV] .......... n_neighbors=9, score=-2009681.833800187, total=   0.0s
# [CV] n_neighbors=9 ...................................................
# [CV] ......... n_neighbors=9, score=-1566922.9206349202, total=   0.0s
# [CV] n_neighbors=9 ...................................................
# [CV] ......... n_neighbors=9, score=-1919389.8314500945, total=   0.0s
# [CV] n_neighbors=9 ...................................................
# [CV] .......... n_neighbors=9, score=-1822029.096986817, total=   0.0s
# [CV] n_neighbors=9 ...................................................
# [CV] ......... n_neighbors=9, score=-1710234.6214689265, total=   0.0s
# [CV] n_neighbors=10 ..................................................
# [CV] ......... n_neighbors=10, score=-2004156.946218487, total=   0.0s
# [CV] n_neighbors=10 ..................................................
# [CV] ........ n_neighbors=10, score=-1525334.5134453783, total=   0.0s
# [CV] n_neighbors=10 ..................................................
# [CV] ........ n_neighbors=10, score=-1906412.7364406781, total=   0.0s
# [CV] n_neighbors=10 ..................................................
# [CV] ........ n_neighbors=10, score=-1845439.1135593224, total=   0.0s
# [CV] n_neighbors=10 ..................................................
# [CV] ........ n_neighbors=10, score=-1727458.3508474578, total=   0.0s
# [CV] n_neighbors=11 ..................................................
# [CV] ........ n_neighbors=11, score=-2003334.4797555385, total=   0.0s
# [CV] n_neighbors=11 ..................................................
# [CV] ......... n_neighbors=11, score=-1555532.754774637, total=   0.0s
# [CV] n_neighbors=11 ..................................................
# [CV] ........ n_neighbors=11, score=-1913853.0778120183, total=   0.0s
# [CV] n_neighbors=11 ..................................................
# [CV] ......... n_neighbors=11, score=-1825326.627118644, total=   0.0s
# [CV] n_neighbors=11 ..................................................
# [CV] ........ n_neighbors=11, score=-1727458.2804314329, total=   0.0s
# [CV] n_neighbors=12 ..................................................
# [CV] ........ n_neighbors=12, score=-1997356.1575630251, total=   0.0s
# [CV] n_neighbors=12 ..................................................
# [CV] ........ n_neighbors=12, score=-1541402.2240896358, total=   0.0s
# [CV] n_neighbors=12 ..................................................
# [CV] ........ n_neighbors=12, score=-1918490.8495762714, total=   0.0s
# [CV] n_neighbors=12 ..................................................
# [CV] ........ n_neighbors=12, score=-1813908.2309322034, total=   0.0s
# [CV] n_neighbors=12 ..................................................
# [CV] ........ n_neighbors=12, score=-1729819.9074858755, total=   0.0s
# [CV] n_neighbors=13 ..................................................
# [CV] ........ n_neighbors=13, score=-1986828.2411118292, total=   0.0s
# [CV] n_neighbors=13 ..................................................
# [CV] ........ n_neighbors=13, score=-1559527.0232708463, total=   0.0s
# [CV] n_neighbors=13 ..................................................
# [CV] ........ n_neighbors=13, score=-1924790.8357235985, total=   0.0s
# [CV] n_neighbors=13 ..................................................
# [CV] ........ n_neighbors=13, score=-1829060.7014341592, total=   0.0s
# [CV] n_neighbors=13 ..................................................
# [CV] ........ n_neighbors=13, score=-1726237.7568448503, total=   0.0s
# [CV] n_neighbors=14 ..................................................
# [CV] ........ n_neighbors=14, score=-1982312.3871548616, total=   0.0s
# [CV] n_neighbors=14 ..................................................
# [CV] ........ n_neighbors=14, score=-1562461.3655462186, total=   0.0s
# [CV] n_neighbors=14 ..................................................
# [CV] ........ n_neighbors=14, score=-1933004.3995157382, total=   0.0s
# [CV] n_neighbors=14 ..................................................
# [CV] ......... n_neighbors=14, score=-1805637.078692494, total=   0.0s
# [CV] n_neighbors=14 ..................................................
# [CV] ......... n_neighbors=14, score=-1715560.464285714, total=   0.0s
# [CV] n_neighbors=15 ..................................................
# [CV] ........ n_neighbors=15, score=-1970186.3327731092, total=   0.0s
# [CV] n_neighbors=15 ..................................................
# [CV] ........ n_neighbors=15, score=-1554108.3523809526, total=   0.0s
# [CV] n_neighbors=15 ..................................................
# [CV] ........ n_neighbors=15, score=-1910087.3322033898, total=   0.0s
# [CV] n_neighbors=15 ..................................................
# [CV] ........ n_neighbors=15, score=-1814239.7141242933, total=   0.0s
# [CV] n_neighbors=15 ..................................................
# [CV] ........ n_neighbors=15, score=-1746068.7327683615, total=   0.0s
# [CV] n_neighbors=16 ..................................................
# [CV] ........ n_neighbors=16, score=-1983813.6454831932, total=   0.0s
# [CV] n_neighbors=16 ..................................................
# [CV] .......... n_neighbors=16, score=-1588277.00052521, total=   0.0s
# [CV] n_neighbors=16 ..................................................
# [CV] ........ n_neighbors=16, score=-1912979.2653601696, total=   0.0s
# [CV] n_neighbors=16 ..................................................
# [CV] ........ n_neighbors=16, score=-1830156.8024364407, total=   0.0s
# [CV] n_neighbors=16 ..................................................
# [CV] ........ n_neighbors=16, score=-1743831.7023305085, total=   0.0s
# [CV] n_neighbors=17 ..................................................
# [CV] ......... n_neighbors=17, score=-1974837.962926347, total=   0.0s
# [CV] n_neighbors=17 ..................................................
# [CV] ......... n_neighbors=17, score=-1580485.955017301, total=   0.0s
# [CV] n_neighbors=17 ..................................................
# [CV] ......... n_neighbors=17, score=-1886681.338983051, total=   0.0s
# [CV] n_neighbors=17 ..................................................
# [CV] ........ n_neighbors=17, score=-1817304.3315054835, total=   0.0s
# [CV] n_neighbors=17 ..................................................
# [CV] ........ n_neighbors=17, score=-1756283.9700897306, total=   0.0s
# [CV] n_neighbors=18 ..................................................
# [CV] ........ n_neighbors=18, score=-1985117.3174603174, total=   0.0s
# [CV] n_neighbors=18 ..................................................
# [CV] ........ n_neighbors=18, score=-1596420.9234360412, total=   0.0s
# [CV] n_neighbors=18 ..................................................
# [CV] ........ n_neighbors=18, score=-1889815.2815442558, total=   0.0s
# [CV] n_neighbors=18 ..................................................
# [CV] .......... n_neighbors=18, score=-1814552.43173258, total=   0.0s
# [CV] n_neighbors=18 ..................................................
# [CV] ........ n_neighbors=18, score=-1772044.6049905836, total=   0.0s
# [CV] n_neighbors=19 ..................................................
# [CV] ........ n_neighbors=19, score=-1995793.1393188853, total=   0.0s
# [CV] n_neighbors=19 ..................................................
# [CV] ........ n_neighbors=19, score=-1589279.0252100844, total=   0.0s
# [CV] n_neighbors=19 ..................................................
# [CV] ........ n_neighbors=19, score=-1914645.4103479034, total=   0.0s
# [CV] n_neighbors=19 ..................................................
# [CV] ........ n_neighbors=19, score=-1826589.7957181085, total=   0.0s
# [CV] n_neighbors=19 ..................................................
# [CV] ........ n_neighbors=19, score=-1756546.4330954505, total=   0.0s
# [CV] n_neighbors=20 ..................................................
# [CV] ........ n_neighbors=20, score=-2003763.4840336135, total=   0.0s
# [CV] n_neighbors=20 ..................................................
# [CV] ........ n_neighbors=20, score=-1595885.3714285716, total=   0.0s
# [CV] n_neighbors=20 ..................................................
# [CV] ........ n_neighbors=20, score=-1913896.6805084746, total=   0.0s
# [CV] n_neighbors=20 ..................................................
# [CV] ........ n_neighbors=20, score=-1815152.6919491524, total=   0.0s
# [CV] n_neighbors=20 ..................................................
# [CV] ......... n_neighbors=20, score=-1770544.595762712, total=   0.0s
# [CV] n_neighbors=21 ..................................................
# [CV] ........ n_neighbors=21, score=-2005946.2965186078, total=   0.0s
# [CV] n_neighbors=21 ..................................................
# [CV] ......... n_neighbors=21, score=-1579896.651860744, total=   0.0s
# [CV] n_neighbors=21 ..................................................
# [CV] ........ n_neighbors=21, score=-1900505.6759483456, total=   0.0s
# [CV] n_neighbors=21 ..................................................
# [CV] ........ n_neighbors=21, score=-1812035.1775625504, total=   0.0s
# [CV] n_neighbors=21 ..................................................
# [CV] ........ n_neighbors=21, score=-1756412.3575464082, total=   0.0s
# [CV] n_neighbors=22 ..................................................
# [CV] ........ n_neighbors=22, score=-2002770.3101604276, total=   0.0s
# [CV] n_neighbors=22 ..................................................
# [CV] ........ n_neighbors=22, score=-1580094.6844919787, total=   0.0s
# [CV] n_neighbors=22 ..................................................
# [CV] ........ n_neighbors=22, score=-1905387.3667180277, total=   0.0s
# [CV] n_neighbors=22 ..................................................
# [CV] ........ n_neighbors=22, score=-1801833.6536979966, total=   0.0s
# [CV] n_neighbors=22 ..................................................
# [CV] ........ n_neighbors=22, score=-1731668.0308166407, total=   0.0s
# [CV] n_neighbors=23 ..................................................
# [CV] ........ n_neighbors=23, score=-2011044.9576178296, total=   0.0s
# [CV] n_neighbors=23 ..................................................
# [CV] ........ n_neighbors=23, score=-1579045.8008768726, total=   0.0s
# [CV] n_neighbors=23 ..................................................
# [CV] ......... n_neighbors=23, score=-1916253.809506264, total=   0.0s
# [CV] n_neighbors=23 ..................................................
# [CV] ........ n_neighbors=23, score=-1796391.8084008843, total=   0.0s
# [CV] n_neighbors=23 ..................................................
# [CV] ........ n_neighbors=23, score=-1724604.0537951363, total=   0.0s
# [CV] n_neighbors=24 ..................................................
# [CV] ........ n_neighbors=24, score=-2004254.9159663864, total=   0.0s
# [CV] n_neighbors=24 ..................................................
# [CV] ........ n_neighbors=24, score=-1575209.0367647056, total=   0.0s
# [CV] n_neighbors=24 ..................................................
# [CV] ........ n_neighbors=24, score=-1900421.6843220335, total=   0.0s
# [CV] n_neighbors=24 ..................................................
# [CV] ........ n_neighbors=24, score=-1804009.1853813562, total=   0.0s
# [CV] n_neighbors=24 ..................................................
# [CV] ........ n_neighbors=24, score=-1712123.4367937853, total=   0.0s
# [CV] n_neighbors=25 ..................................................
# [CV] ........ n_neighbors=25, score=-2007740.0588235294, total=   0.0s
# [CV] n_neighbors=25 ..................................................
# [CV] ......... n_neighbors=25, score=-1566529.994285714, total=   0.0s
# [CV] n_neighbors=25 ..................................................
# [CV] ........ n_neighbors=25, score=-1895391.7159322032, total=   0.0s
# [CV] n_neighbors=25 ..................................................
# [CV] ........ n_neighbors=25, score=-1797297.9769491525, total=   0.0s
# [CV] n_neighbors=25 ..................................................
# [CV] ........ n_neighbors=25, score=-1713975.8291525424, total=   0.0s
# [CV] n_neighbors=26 ..................................................
# [CV] ........ n_neighbors=26, score=-2009066.6376858435, total=   0.0s
# [CV] n_neighbors=26 ..................................................
# [CV] ........ n_neighbors=26, score=-1555148.8723335487, total=   0.0s
# [CV] n_neighbors=26 ..................................................
# [CV] ........ n_neighbors=26, score=-1896503.4416558016, total=   0.0s
# [CV] n_neighbors=26 ..................................................
# [CV] ........ n_neighbors=26, score=-1800585.8073663625, total=   0.0s
# [CV] n_neighbors=26 ..................................................
# [CV] ........ n_neighbors=26, score=-1714621.9696870924, total=   0.0s
# [CV] n_neighbors=27 ..................................................
# [CV] ........ n_neighbors=27, score=-2005961.6013071893, total=   0.0s
# [CV] n_neighbors=27 ..................................................
# [CV] ........ n_neighbors=27, score=-1551516.5091814501, total=   0.0s
# [CV] n_neighbors=27 ..................................................
# [CV] ........ n_neighbors=27, score=-1882491.0423728807, total=   0.0s
# [CV] n_neighbors=27 ..................................................
# [CV] ........ n_neighbors=27, score=-1797199.6858129317, total=   0.0s
# [CV] n_neighbors=27 ..................................................
# [CV] ........ n_neighbors=27, score=-1717001.2548650345, total=   0.0s
# [CV] n_neighbors=28 ..................................................
# [CV] ........ n_neighbors=28, score=-2013365.9573829533, total=   0.0s
# [CV] n_neighbors=28 ..................................................
# [CV] ........ n_neighbors=28, score=-1552930.6635654261, total=   0.0s
# [CV] n_neighbors=28 ..................................................
# [CV] ........ n_neighbors=28, score=-1885452.2490920094, total=   0.0s
# [CV] n_neighbors=28 ..................................................
# [CV] ........ n_neighbors=28, score=-1784637.0018159808, total=   0.0s
# [CV] n_neighbors=28 ..................................................
# [CV] ........ n_neighbors=28, score=-1715459.8986077479, total=   0.0s
# [CV] n_neighbors=29 ..................................................
# [CV] ........ n_neighbors=29, score=-2012089.9776876266, total=   0.0s
# [CV] n_neighbors=29 ..................................................
# [CV] ......... n_neighbors=29, score=-1543337.345696899, total=   0.0s
# [CV] n_neighbors=29 ..................................................
# [CV] ........ n_neighbors=29, score=-1896067.1043249557, total=   0.0s
# [CV] n_neighbors=29 ..................................................
# [CV] ........ n_neighbors=29, score=-1788086.9038573927, total=   0.0s
# [CV] n_neighbors=29 ..................................................
# [CV] ........ n_neighbors=29, score=-1717305.0073056694, total=   0.0s
# [CV] n_neighbors=30 ..................................................
# [CV] ........ n_neighbors=30, score=-2016903.8834733893, total=   0.0s
# [CV] n_neighbors=30 ..................................................
# [CV] ........ n_neighbors=30, score=-1548165.2661064425, total=   0.0s
# [CV] n_neighbors=30 ..................................................
# [CV] ........ n_neighbors=30, score=-1890138.9186440674, total=   0.0s
# [CV] n_neighbors=30 ..................................................
# [CV] ........ n_neighbors=30, score=-1789929.2844632773, total=   0.0s
# [CV] n_neighbors=30 ..................................................
# [CV] ........ n_neighbors=30, score=-1726104.0045197743, total=   0.0s
# [CV] n_neighbors=31 ..................................................
# [CV] ......... n_neighbors=31, score=-2012477.664678775, total=   0.0s
# [CV] n_neighbors=31 ..................................................
# [CV] ........ n_neighbors=31, score=-1557692.4109514775, total=   0.0s
# [CV] n_neighbors=31 ..................................................
# [CV] ........ n_neighbors=31, score=-1881011.9969928921, total=   0.0s
# [CV] n_neighbors=31 ..................................................
# [CV] ........ n_neighbors=31, score=-1796871.6962821211, total=   0.0s
# [CV] n_neighbors=31 ..................................................
# [CV] ........ n_neighbors=31, score=-1730047.9789502462, total=   0.0s
# [CV] n_neighbors=32 ..................................................
# [CV] ........ n_neighbors=32, score=-2011675.8658088236, total=   0.0s
# [CV] n_neighbors=32 ..................................................
# [CV] .......... n_neighbors=32, score=-1556205.56197479, total=   0.0s
# [CV] n_neighbors=32 ..................................................
# [CV] ........ n_neighbors=32, score=-1885806.1043432204, total=   0.0s
# [CV] n_neighbors=32 ..................................................
# [CV] ........ n_neighbors=32, score=-1791895.1207627119, total=   0.0s
# [CV] n_neighbors=32 ..................................................
# [CV] ........ n_neighbors=32, score=-1727770.4192266949, total=   0.0s
# [CV] n_neighbors=33 ..................................................
# [CV] ......... n_neighbors=33, score=-2011439.600458365, total=   0.0s
# [CV] n_neighbors=33 ..................................................
# [CV] ......... n_neighbors=33, score=-1565092.361344538, total=   0.0s
# [CV] n_neighbors=33 ..................................................
# [CV] ........ n_neighbors=33, score=-1891912.6153055984, total=   0.0s
# [CV] n_neighbors=33 ..................................................
# [CV] ........ n_neighbors=33, score=-1798009.3495120702, total=   0.0s
# [CV] n_neighbors=33 ..................................................
# [CV] ........ n_neighbors=33, score=-1730559.6815613764, total=   0.0s
# [CV] n_neighbors=34 ..................................................
# [CV] ........ n_neighbors=34, score=-2014350.7241720217, total=   0.0s
# [CV] n_neighbors=34 ..................................................
# [CV] ........ n_neighbors=34, score=-1564957.8643104297, total=   0.0s
# [CV] n_neighbors=34 ..................................................
# [CV] ........ n_neighbors=34, score=-1897040.1238783654, total=   0.0s
# [CV] n_neighbors=34 ..................................................
# [CV] ......... n_neighbors=34, score=-1796897.814307079, total=   0.0s
# [CV] n_neighbors=34 ..................................................
# [CV] ........ n_neighbors=34, score=-1732991.4748255233, total=   0.0s
# [CV] n_neighbors=35 ..................................................
# [CV] ........ n_neighbors=35, score=-2010521.4367346938, total=   0.0s
# [CV] n_neighbors=35 ..................................................
# [CV] ........ n_neighbors=35, score=-1556526.4506602641, total=   0.0s
# [CV] n_neighbors=35 ..................................................
# [CV] ........ n_neighbors=35, score=-1889534.3820823245, total=   0.0s
# [CV] n_neighbors=35 ..................................................
# [CV] ........ n_neighbors=35, score=-1792526.8360774817, total=   0.0s
# [CV] n_neighbors=35 ..................................................
# [CV] ........ n_neighbors=35, score=-1732713.9169491525, total=   0.0s
# [CV] n_neighbors=36 ..................................................
# [CV] ........ n_neighbors=36, score=-2008013.0074696543, total=   0.0s
# [CV] n_neighbors=36 ..................................................
# [CV] ........ n_neighbors=36, score=-1560162.9239028946, total=   0.0s
# [CV] n_neighbors=36 ..................................................
# [CV] ........ n_neighbors=36, score=-1883414.3841807907, total=   0.0s
# [CV] n_neighbors=36 ..................................................
# [CV] ........ n_neighbors=36, score=-1792125.1247645952, total=   0.0s
# [CV] n_neighbors=36 ..................................................
# [CV] ........ n_neighbors=36, score=-1738458.9121939738, total=   0.0s
# [CV] n_neighbors=37 ..................................................
# [CV] ........ n_neighbors=37, score=-2015607.2736770378, total=   0.0s
# [CV] n_neighbors=37 ..................................................
# [CV] ........ n_neighbors=37, score=-1568841.9677492622, total=   0.0s
# [CV] n_neighbors=37 ..................................................
# [CV] ......... n_neighbors=37, score=-1885775.987173614, total=   0.0s
# [CV] n_neighbors=37 ..................................................
# [CV] ......... n_neighbors=37, score=-1779701.604672469, total=   0.0s
# [CV] n_neighbors=37 ..................................................
# [CV] ........ n_neighbors=37, score=-1743018.7439303715, total=   0.0s
# [CV] n_neighbors=38 ..................................................
# [CV] ........ n_neighbors=38, score=-2012246.7328615657, total=   0.0s
# [CV] n_neighbors=38 ..................................................
# [CV] ........ n_neighbors=38, score=-1561142.4520123838, total=   0.0s
# [CV] n_neighbors=38 ..................................................
# [CV] ........ n_neighbors=38, score=-1891967.1320249778, total=   0.0s
# [CV] n_neighbors=38 ..................................................
# [CV] ........ n_neighbors=38, score=-1776481.0706958072, total=   0.0s
# [CV] n_neighbors=38 ..................................................
# [CV] ........ n_neighbors=38, score=-1749833.5272078502, total=   0.0s
# [CV] n_neighbors=39 ..................................................
# [CV] ........ n_neighbors=39, score=-2011622.6645119586, total=   0.0s
# [CV] n_neighbors=39 ..................................................
# [CV] ........ n_neighbors=39, score=-1562998.8508942036, total=   0.0s
# [CV] n_neighbors=39 ..................................................
# [CV] ......... n_neighbors=39, score=-1896304.781182095, total=   0.0s
# [CV] n_neighbors=39 ..................................................
# [CV] ........ n_neighbors=39, score=-1776142.0691003911, total=   0.0s
# [CV] n_neighbors=39 ..................................................
# [CV] ........ n_neighbors=39, score=-1747439.9674054761, total=   0.0s
# [CV] n_neighbors=40 ..................................................
# [CV] ........ n_neighbors=40, score=-2011186.7325630256, total=   0.0s
# [CV] n_neighbors=40 ..................................................
# [CV] ........ n_neighbors=40, score=-1560810.5533613442, total=   0.0s
# [CV] n_neighbors=40 ..................................................
# [CV] ........ n_neighbors=40, score=-1894162.7114406778, total=   0.0s
# [CV] n_neighbors=40 ..................................................
# [CV] ........ n_neighbors=40, score=-1765128.6228813557, total=   0.0s
# [CV] n_neighbors=40 ..................................................
# [CV] ........ n_neighbors=40, score=-1750838.4567796611, total=   0.0s
# [CV] n_neighbors=41 ..................................................
# [CV] ........ n_neighbors=41, score=-2001653.0713260914, total=   0.0s
# [CV] n_neighbors=41 ..................................................
# [CV] ......... n_neighbors=41, score=-1566578.405615905, total=   0.0s
# [CV] n_neighbors=41 ..................................................
# [CV] ........ n_neighbors=41, score=-1894804.2364613472, total=   0.0s
# [CV] n_neighbors=41 ..................................................
# [CV] ......... n_neighbors=41, score=-1767435.630632493, total=   0.0s
# [CV] n_neighbors=41 ..................................................
# [CV] ........ n_neighbors=41, score=-1747860.2505167425, total=   0.0s
# [CV] n_neighbors=42 ..................................................
# [CV] ........ n_neighbors=42, score=-2003057.7821128448, total=   0.0s
# [CV] n_neighbors=42 ..................................................
# [CV] ........ n_neighbors=42, score=-1557290.2841136453, total=   0.0s
# [CV] n_neighbors=42 ..................................................
# [CV] .......... n_neighbors=42, score=-1895999.61622276, total=   0.0s
# [CV] n_neighbors=42 ..................................................
# [CV] ........ n_neighbors=42, score=-1764743.0189669083, total=   0.0s
# [CV] n_neighbors=42 ..................................................
# [CV] ........ n_neighbors=42, score=-1744858.8730831319, total=   0.0s
# [CV] n_neighbors=43 ..................................................
# [CV] ........ n_neighbors=43, score=-2001723.3521594682, total=   0.0s
# [CV] n_neighbors=43 ..................................................
# [CV] ........ n_neighbors=43, score=-1550797.1053351571, total=   0.0s
# [CV] n_neighbors=43 ..................................................
# [CV] ........ n_neighbors=43, score=-1896212.3427276309, total=   0.0s
# [CV] n_neighbors=43 ..................................................
# [CV] ......... n_neighbors=43, score=-1761005.349822625, total=   0.0s
# [CV] n_neighbors=43 ..................................................
# [CV] ......... n_neighbors=43, score=-1748052.373866772, total=   0.0s
# [CV] n_neighbors=44 ..................................................
# [CV] ........ n_neighbors=44, score=-1997267.2941176468, total=   0.0s
# [CV] n_neighbors=44 ..................................................
# [CV] ......... n_neighbors=44, score=-1550104.889801375, total=   0.0s
# [CV] n_neighbors=44 ..................................................
# [CV] ........ n_neighbors=44, score=-1894806.5021186438, total=   0.0s
# [CV] n_neighbors=44 ..................................................
# [CV] ........ n_neighbors=44, score=-1765013.0606702617, total=   0.0s
# [CV] n_neighbors=44 ..................................................
# [CV] ........ n_neighbors=44, score=-1743948.2652157166, total=   0.0s
# [CV] n_neighbors=45 ..................................................
# [CV] ........ n_neighbors=45, score=-1995716.4857142856, total=   0.0s
# [CV] n_neighbors=45 ..................................................
# [CV] ........ n_neighbors=45, score=-1554726.2212885155, total=   0.0s
# [CV] n_neighbors=45 ..................................................
# [CV] ......... n_neighbors=45, score=-1895351.694915254, total=   0.0s
# [CV] n_neighbors=45 ..................................................
# [CV] ........ n_neighbors=45, score=-1754925.3758945384, total=   0.0s
# [CV] n_neighbors=45 ..................................................
# [CV] ........ n_neighbors=45, score=-1754684.5939736343, total=   0.0s
# [CV] n_neighbors=46 ..................................................
# [CV] ........ n_neighbors=46, score=-1997577.3222506398, total=   0.0s
# [CV] n_neighbors=46 ..................................................
# [CV] ........ n_neighbors=46, score=-1554895.7908293756, total=   0.0s
# [CV] n_neighbors=46 ..................................................
# [CV] ......... n_neighbors=46, score=-1895553.484156227, total=   0.0s
# [CV] n_neighbors=46 ..................................................
# [CV] ........ n_neighbors=46, score=-1754269.1665438472, total=   0.0s
# [CV] n_neighbors=46 ..................................................
# [CV] ........ n_neighbors=46, score=-1757485.0018422992, total=   0.0s
# [CV] n_neighbors=47 ..................................................
# [CV] ........ n_neighbors=47, score=-1989030.4308957628, total=   0.0s
# [CV] n_neighbors=47 ..................................................
# [CV] ........ n_neighbors=47, score=-1551896.4128374753, total=   0.0s
# [CV] n_neighbors=47 ..................................................
# [CV] ........ n_neighbors=47, score=-1899104.4976559682, total=   0.0s
# [CV] n_neighbors=47 ..................................................
# [CV] ........ n_neighbors=47, score=-1746285.9426613774, total=   0.0s
# [CV] n_neighbors=47 ..................................................
# [CV] ........ n_neighbors=47, score=-1749898.3523260008, total=   0.0s
# [CV] n_neighbors=48 ..................................................
# [CV] ......... n_neighbors=48, score=-1989147.764530812, total=   0.0s
# [CV] n_neighbors=48 ..................................................
# [CV] ........ n_neighbors=48, score=-1548523.4527310925, total=   0.0s
# [CV] n_neighbors=48 ..................................................
# [CV] ........ n_neighbors=48, score=-1904219.8200918082, total=   0.0s
# [CV] n_neighbors=48 ..................................................
# [CV] ........ n_neighbors=48, score=-1752714.8905367234, total=   0.0s
# [CV] n_neighbors=48 ..................................................
# [CV] ........ n_neighbors=48, score=-1746136.1036370052, total=   0.0s
# [CV] n_neighbors=49 ..................................................
# [CV] ......... n_neighbors=49, score=-1991634.671754416, total=   0.0s
# [CV] n_neighbors=49 ..................................................
# [CV] ........ n_neighbors=49, score=-1540249.1281083864, total=   0.0s
# [CV] n_neighbors=49 ..................................................
# [CV] ......... n_neighbors=49, score=-1897710.827914216, total=   0.0s
# [CV] n_neighbors=49 ..................................................
# [CV] ........ n_neighbors=49, score=-1748061.1921480456, total=   0.0s
# [CV] n_neighbors=49 ..................................................
# [CV] ......... n_neighbors=49, score=-1750780.010377032, total=   0.0s
# {'n_neighbors': 49}
# -1785620.4590802537
# [Parallel(n_jobs=1)]: Done 235 out of 235 | elapsed:    2.0s finished
# C:\Users\ES71531200G\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
regGsKN = regGsCvKN.best_estimator_

# %%
# Do predictions
y_regGsKN_pred = regGsKN.predict(X_test)

# %%
print(np.mean(np.abs(y_test-y_regGsKN_pred)))
print("Mean error represents ", round(100*np.mean(np.abs(y_test-y_regGsKN_pred))/df_modelize5['INTEGRAL_COSTS'].mean()), "% from the mean value")
plt.hist(y_test-y_regGsKN_pred,bins=50);
# Out:
# 1710828.790816327
# Mean error represents  -46 % from the mean value

# %% [markdown]
# ## Third: Decision Trees

# %% [markdown]
# A simple decision tree

# %%
# Load the library
from sklearn.tree import DecisionTreeRegressor
# Create an instance
regDT = DecisionTreeRegressor(max_depth=10)
# Fit the data
regDT.fit(X_train,y_train)
# Do predictions
y_regDT_pred = regDT.predict(X_test)

# %%
print(np.mean(np.abs(y_test-y_regDT_pred)))
print("Mean error represents ", round(100*np.mean(np.abs(y_test-y_regDT_pred))/df_modelize5['INTEGRAL_COSTS'].mean()), "% from the mean value")
plt.hist(y_test-y_regDT_pred,bins=50);
# Out:
# 1152809.175793651
# Mean error represents  -31 % from the mean value

# %% [markdown]
# Now a random forest with GridSearchCV for finding the best parametres possible

# %%
# Import Library
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Create instance
regRF = GridSearchCV(RandomForestRegressor(),n_jobs=-1,
                  param_grid = {"min_samples_leaf":[1,2,3],
                               "max_depth":np.arange(3,20),
                               "n_estimators":[500]},
                  cv=5,
                  scoring="neg_mean_absolute_error",
                  verbose=9)
                     
                     
# Fit will test all of the combinations
regRF.fit(X_train,y_train)


print(regRF.best_params_)
print(regRF.best_score_)

regRFF = regRF.best_estimator_
# Out:
# Fitting 5 folds for each of 51 candidates, totalling 255 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   42.2s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=-1)]: Done 255 out of 255 | elapsed:   57.2s finished
# C:\Users\ES71531200G\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'max_depth': 15, 'min_samples_leaf': 2, 'n_estimators': 500}
# -1065329.980112878

# %%
# Do predictions
y_regRFF_pred = regRFF.predict(X_test)

# %%
print(np.mean(np.abs(y_test-y_regRFF_pred)))
print("Mean error represents ", round(100*np.mean(np.abs(y_test-y_regRFF_pred))/df_modelize5['INTEGRAL_COSTS'].mean()), "% from the mean value")
plt.hist(y_test-y_regRFF_pred,bins=50);
# Out:
# 1092751.8666766812
# Mean error represents  -29 % from the mean value

# %% [markdown]
# Finally an xgBooster

# %%
# Load the library
import xgboost as XGB
# Create an instance
regXGB = XGB.XGBRegressor(n_estimators=100, 
                          learning_rate=0.08, 
                          gamma=0, 
                          subsample=0.75,
                          colsample_bytree=1, 
                          max_depth=7)
# Fit the data
regXGB.fit(X_train,y_train)
# Do predictions
y_regXGB_pred = regXGB.predict(X_test)

# %%
print(np.mean(np.abs(y_test-y_regXGB_pred)))
print("Mean error represents ", round(100*np.mean(np.abs(y_test-y_regXGB_pred))/df_modelize5['INTEGRAL_COSTS'].mean()), "% from the mean value")
plt.hist(y_test-y_regXGB_pred,bins=50);
# Out:
# 1049640.0608723958
# Mean error represents  -28 % from the mean value

# %%
# Load the library
from sklearn.model_selection import GridSearchCV
import xgboost as XGB

# %%
# Load the library
from sklearn.model_selection import GridSearchCV
from xgboost.sklearn import XGBRegressor
# Create an instance
        
xgb1 = XGBRegressor()
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

regXGB = GridSearchCV(xgb1,
                        parameters,
                        cv = 5,
                        n_jobs = -1,
                        scoring="neg_mean_absolute_error",
                        verbose=9)

# Fit the data
regXGB.fit(X_train,y_train)


print(regXGB.best_params_)
print(regXGB.best_score_)

regXGB = regXGB.best_estimator_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:   17.3s finished
# C:\Users\ES71531200G\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'colsample_bytree': 0.7, 'learning_rate': 0.03, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 500, 'nthread': 4, 'silent': 1, 'subsample': 0.7}
# -1025438.832626687

# %%
# Do predictions
y_regXGB_pred = regXGB.predict(X_test)
print(np.mean(np.abs(y_test-y_regXGB_pred)))
print("Mean error represents ", round(100*np.mean(np.abs(y_test-y_regXGB_pred))/df_modelize5['INTEGRAL_COSTS'].mean()), "% from the mean value")
plt.hist(y_test-y_regXGB_pred,bins=50);
# Out:
# 1092090.7065104167
# Mean error represents  -29 % from the mean value

# %% [markdown]
# ## Fourth and Last (I hope): Support Vector Machine Regression

# %%
# Load the library
from sklearn.svm import SVR
# Create an instance
regSVR = SVR(kernel="rbf",C=0.1)
# Fit the data
regSVR.fit(X_train,y_train)
# Do predictions
y_regSVR_pred = regSVR.predict(X_test)
# Out:
# C:\Users\ES71531200G\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
print(np.mean(np.abs(y_test-y_regSVR_pred)))
print("Mean error represents ", round(100*np.mean(np.abs(y_test-y_regSVR_pred))/df_modelize5['INTEGRAL_COSTS'].mean()), "% from the mean value")
plt.hist(y_test-y_regSVR_pred,bins=50);
# Out:
# 9241627.0
# Mean error represents  -78 % from the mean value

# %% [markdown]
# # Representation

# %%
import numpy as np
import matplotlib.pyplot as plt

df_temp = df_modelize5
df_temp['VERSION'] = pd.to_datetime(df_modelize5['VERSION'], format='%Y%m', errors='coerce').dropna()

for i in range(1,9):
    tech = i
    plt.plot(df_temp[df_modelize5['NUM_TECH'] == tech]['VERSION'], df_temp[df_modelize5['NUM_TECH'] == tech]['INTEGRAL_COSTS'], '-o')
    legend(range(1,9))

plt.show(figsize(30,10))

# %%
import numpy as np
import matplotlib.pyplot as plt

df_temp = df_modelize5
df_temp['VERSION'] = pd.to_datetime(df_modelize5['VERSION'], format='%Y%m', errors='coerce').dropna()


tech = 8
plt.plot(df_temp[df_modelize5['NUM_TECH'] == tech]['VERSION'], df_temp[df_modelize5['NUM_TECH'] == tech]['INTEGRAL_COSTS'], '-o')
plt.plot(df_temp[df_modelize5['NUM_TECH'] == tech]['VERSION'], df_temp[df_modelize5['NUM_TECH'] == tech]['POWER_MWH'], '-o')
print(df_tech)
plt.show(figsize(30,10))
# Out:
#    ID_TECNOLOGIA  NUM_TECH
# 0             NC         1
# 3             EB         2
# 4             BX         3
# 6             BP         4
# 8             GN         5
# 10            CI         6
# 21            HN         7
# 27            LN         8
