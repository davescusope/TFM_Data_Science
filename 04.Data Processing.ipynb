# %% [markdown]
# # Python TFM Section

# %% [markdown]
# ## Data Processing
#
# On this section of the TFM it will be done all the preparation needed for the model:
#
# 1. Import all the .csv created on the R section to unify them
# 2. Set up a unique data frame where we will have all the variables and information required to the regression model
# 3. Unstack the structure for making it more suitable to be used on a model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
#!conda install --yes pathlib 
#$ python -m pip install pathlib

# %%
from pathlib import Path

# %%
print(Path.cwd())
# Out:
# C:\Users\ES71531200G\Desktop\Data Science\00.TFM

# %%
#Defining path to files from the imports folder
# %pwd

file1 = "COSTES_E4E_EUROS.csv"
file2 = "LIQUIDACIONES_EUROS.csv"
file3 = "NUCLEAR_WASTES_EUROS.csv"

file5 = "LIQUIDACIONES_MWH.csv"

File_list = [file1, file2, file3]
del(file1,file2,file3)


File_list
# Out:
# ['COSTES_E4E_EUROS.csv', 'LIQUIDACIONES_EUROS.csv', 'NUCLEAR_WASTES_EUROS.csv']

# %%
# %whos
# Out:
# Variable    Type      Data/Info
# -------------------------------
# File_list   list      n=3
# Path        type      <class 'pathlib.Path'>
# file5       str       LIQUIDACIONES_MWH.csv
# np          module    <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd          module    <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt         module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>

# %% [markdown]
# Importing directly with the read_csv function retrieves an error due to the encoding used by R during the exportation
# The parametres encoding and sep solve the probem

# %%
inputpath1 = Path.cwd() / 'Outputs' / 'COSTES_E4E_EUROS.csv' 
df1 = pd.read_csv(inputpath1, sep = ';', header = 0 , encoding = "ISO-8859-1")

# %% [markdown]
# I create a df with the same columnames and data types but no rows for using it as the initial frame to append everything alltogheter.

# %%
dfTotal = df1[0:0]
del(df1)
dfTotal
# Out:
# Empty DataFrame
# Columns: [VERSION, ID_UPR, ID_TECNOLOGIA, ID_GRUPO_EMPRESARIAL, ID_AREA_SISTEMA, ID_CONCEPTO_CTRL, VALOR, ID_UNIDAD]
# Index: []

# %%
path_list = []
for file in File_list:
    inputpath = Path.cwd() / 'Outputs' / file
    print (inputpath)
    df1 = pd.read_csv(inputpath, sep = ';', header = 0 , encoding = "ISO-8859-1")
    dfTotal = dfTotal.append(df1)
# Out:
# C:\Users\ES71531200G\Desktop\Data Science\00.TFM\Outputs\COSTES_E4E_EUROS.csv
# C:\Users\ES71531200G\Desktop\Data Science\00.TFM\Outputs\LIQUIDACIONES_EUROS.csv
# C:\Users\ES71531200G\Desktop\Data Science\00.TFM\Outputs\NUCLEAR_WASTES_EUROS.csv
# C:\Users\ES71531200G\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %% [markdown]
# The process comes back a warning saying that one column is nmissing in at least one section, so we explore the data to see what's happening

# %%
dfTotal.sample(20)
# Out:
#       ID_AREA_SISTEMA           ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL  \
# 11743             NaN              R. Secundaria             EMPRESA3
# 7042              NaN                  Terciaria             EMPRESA3
# 15800             NaN     S. Res. Pot. Adicional             EMPRESA1
# 1165              NaN             G. Potencia MP             EMPRESA1
# 11543             NaN                  Terciaria             EMPRESA2
# 82             ESPAÑA                    CALIZAS             EMPRESA1
# 5962              NaN                  Terciaria             EMPRESA1
# 219               NaN                 G. Desvios             EMPRESA3
# 4913              NaN                  M. Diario             EMPRESA1
# 13100             NaN                  Terciaria             EMPRESA3
# 5660              NaN                  M. Diario             EMPRESA1
# 2250              NaN            M. Intradiarios             EMPRESA3
# 8580              NaN  I. G. Desvíos y Terciaria             EMPRESA1
# 3973              NaN            M. Intradiarios             EMPRESA2
# 17037             NaN                     Ajuste             EMPRESA1
# 15675             NaN                  M. Diario             EMPRESA1
# 16245             NaN    M. Intradiario Continuo             EMPRESA1
# 15790             NaN              R. Secundaria             EMPRESA3
# 4477           ESPAÑA                  PEAJE GEN             EMPRESA1
# 12002             NaN                Redespachos             EMPRESA1
#
#       ID_TECNOLOGIA ID_UNIDAD   ID_UPR          VALOR  VERSION
# 11743            GN     EUROS   UPR318       -41677,8   201803
# 7042             GN     EUROS   UPR161        9255238   201710
# 15800            BP     EUROS  UPR1752      -13145,52   201809
# 1165             GN     EUROS  UPR1864        1058181   201702
# 11543            BX     EUROS  UPR2261         151,04   201803
# 82               HN     EUROS   UPR194  -1,951940e+04   201701
# 5962             BP     EUROS  UPR2415      -306694,7   201708
# 219              HN     EUROS  UPR1803       11282,75   201701
# 4913             CI     EUROS  UPR1860      151916371   201707
# 13100            EB     EUROS  UPR2600        3779883   201805
# 5660             CI     EUROS  UPR1860      114992325   201708
# 2250             BP     EUROS  UPR2586      -313784,7   201703
# 8580             EB     EUROS   UPR418        -620502   201711
# 3973             EB     EUROS  UPR1623       66212,43   201706
# 17037            HN     EUROS   UPR304       -2665933   201810
# 15675            BP     EUROS  UPR1314      -464722,5   201809
# 16245            HN     EUROS   UPR304       -4716771   201809
# 15790            CI     EUROS  UPR1721       -9450765   201809
# 4477             CI     EUROS  UPR1661  -1,885358e+05   201810
# 12002            CI     EUROS  UPR1662      -211833,3   201804

# %% [markdown]
# We obserb that the file "LIQUIDACIONES_EUROS" doesn't have the column ID_AREA_SISTEMA.
# To overpass this situations, I proceed to replace all the NaNs with the right values through the selection of the unique tuples
# [ID_AREA_SISTEMA - ID_UPR].

# %%
df_aux = dfTotal[['ID_AREA_SISTEMA', 'ID_UPR']].dropna().drop_duplicates()
df_aux.sample(10)
# Out:
#     ID_AREA_SISTEMA   ID_UPR
# 82           ESPAÑA   UPR194
# 89           ESPAÑA  UPR2103
# 120          ESPAÑA  UPR2343
# 14           ESPAÑA  UPR1206
# 159          ESPAÑA   UPR417
# 100          ESPAÑA  UPR2331
# 45           ESPAÑA  UPR1752
# 24           ESPAÑA   UPR160
# 104          ESPAÑA  UPR2341
# 112          ESPAÑA  UPR2342

# %% [markdown]
# And now I will replace the values using a left join with pandas

# %%
df_merged = pd.merge(dfTotal, df_aux, on='ID_UPR', how='left')
df_merged.sample(10)
df_merged.columns
# Out:
# Index(['ID_AREA_SISTEMA_x', 'ID_CONCEPTO_CTRL', 'ID_GRUPO_EMPRESARIAL',
#        'ID_TECNOLOGIA', 'ID_UNIDAD', 'ID_UPR', 'VALOR', 'VERSION',
#        'ID_AREA_SISTEMA_y'],
#       dtype='object')

# %%
df_merged = df_merged.rename(columns={'ID_AREA_SISTEMA_y': 'ID_AREA_SISTEMA'})
df_merged = df_merged.drop(columns="ID_AREA_SISTEMA_x")
print(df_merged.columns)
df_merged.sample(10)
# Out:
# Index(['ID_CONCEPTO_CTRL', 'ID_GRUPO_EMPRESARIAL', 'ID_TECNOLOGIA',
#        'ID_UNIDAD', 'ID_UPR', 'VALOR', 'VERSION', 'ID_AREA_SISTEMA'],
#       dtype='object')
#                 ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA ID_UNIDAD  \
# 14406  I. G. Desvíos y Terciaria             EMPRESA1            LN     EUROS
# 18817                      Banda             EMPRESA1            EB     EUROS
# 1825                    AMONIACO             EMPRESA1            LN     EUROS
# 4100                       OTROS             EMPRESA1            LN     EUROS
# 5483                         VCF             EMPRESA1            CI     EUROS
# 10699             G. Potencia MP             EMPRESA1            CI     EUROS
# 16021         D. Medida Contador             EMPRESA1            NC     EUROS
# 18083                Redespachos             EMPRESA2            BP     EUROS
# 10214            M. Intradiarios             EMPRESA2            BP     EUROS
# 14905  I. G. Desvíos y Terciaria             EMPRESA1            BP     EUROS
#
#         ID_UPR          VALOR  VERSION ID_AREA_SISTEMA
# 14406  UPR2343      -99310,51   201712          ESPAÑA
# 18817  UPR2103        1257887   201806          ESPAÑA
# 1825   UPR2342  -7,255110e+03   201710          ESPAÑA
# 4100   UPR2343   1,458979e+04   201808          ESPAÑA
# 5483   UPR1863      -24716,55   201701          ESPAÑA
# 10699  UPR1661        3400514   201708          ESPAÑA
# 16021  UPR2491      -2874,566   201802          ESPAÑA
# 18083  UPR2134      -110431,9   201805             NaN
# 10214  UPR2134       -2352078   201707             NaN
# 14905  UPR1752      -255651,6   201801          ESPAÑA

# %%
df_merged = df_merged[df_merged['ID_GRUPO_EMPRESARIAL'] == 'EMPRESA1']
df_merged.sample(10)
# Out:
#                 ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA ID_UNIDAD  \
# 9295   I. G. Desvíos y Terciaria             EMPRESA1            CI     EUROS
# 12249             G. Potencia MP             EMPRESA1            CI     EUROS
# 22910  I. G. Desvíos y Terciaria             EMPRESA1            BP     EUROS
# 17142                      Banda             EMPRESA1            CI     EUROS
# 534                      CALIZAS             EMPRESA1            HN     EUROS
# 3864                   PEAJE GEN             EMPRESA1            EB     EUROS
# 7347             M. Intradiarios             EMPRESA1            LN     EUROS
# 18981                  Terciaria             EMPRESA1            EB     EUROS
# 15313             G. Potencia MP             EMPRESA1            GN     EUROS
# 15889                     Ajuste             EMPRESA1            BP     EUROS
#
#         ID_UPR          VALOR  VERSION ID_AREA_SISTEMA
# 9295   UPR1861      -126918,2   201706          ESPAÑA
# 12249  UPR1661        4290329   201710          ESPAÑA
# 22910  UPR2414      -246715,5   201811          ESPAÑA
# 17142  UPR1661        4012416   201804          ESPAÑA
# 534     UPR304  -2,040799e+04   201703          ESPAÑA
# 3864   UPR2344  -8,721492e+03   201807          ESPAÑA
# 7347   UPR2342        1797773   201703          ESPAÑA
# 18981  UPR2344      -104060,9   201806          ESPAÑA
# 15313   UPR300        4011557   201801          ESPAÑA
# 15889  UPR2141       -3439387   201802             NaN

# %%
df_merged[df_merged['ID_AREA_SISTEMA'].isna()].head(5)
# Out:
#             ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA ID_UNIDAD  \
# 5189      D. Medida Contador             EMPRESA1            NC     EUROS
# 5190  S. Res. Pot. Adicional             EMPRESA1            NC     EUROS
# 5349                  Ajuste             EMPRESA1            BP     EUROS
# 5350               Bilateral             EMPRESA1            BP     EUROS
# 5351      D. Medida Contador             EMPRESA1            BP     EUROS
#
#        ID_UPR      VALOR  VERSION ID_AREA_SISTEMA
# 5189  UPR1198  -35305,63   201701             NaN
# 5190  UPR1198     -192,8   201701             NaN
# 5349  UPR1751  -374890,6   201701             NaN
# 5350  UPR1751  -213155,6   201701             NaN
# 5351  UPR1751  -22453,97   201701             NaN

# %% [markdown]
# There are still NaN values, but thanks to our knowledge from the original data, we know that there are ONLY 2 UPRs with ID_AREA_SISTEMA = 'Portugal', what means that every NaN value right now should be equal to ESPAÑA, so we replace now all the NANs

# %%
df_merged = df_merged.fillna('ESPAÑA')
df_merged.sample(10)
# Out:
#              ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA ID_UNIDAD  \
# 6103   S. Res. Pot. Adicional             EMPRESA1            BP     EUROS
# 21107  I. Res. Pot. Adicional             EMPRESA1            HN     EUROS
# 3224           IMPUESTO ELECT             EMPRESA1            EB     EUROS
# 17956                  Ajuste             EMPRESA1            CI     EUROS
# 10246      D. Medida Contador             EMPRESA1            GN     EUROS
# 6517                Terciaria             EMPRESA1            EB     EUROS
# 8886               G. Desvios             EMPRESA1            HN     EUROS
# 8514           G. Potencia LP             EMPRESA1            GN     EUROS
# 6330           G. Potencia LP             EMPRESA1            GN     EUROS
# 4300           IMPUESTO ELECT             EMPRESA1            EB     EUROS
#
#         ID_UPR          VALOR  VERSION ID_AREA_SISTEMA
# 6103   UPR1314          -4,62   201702          ESPAÑA
# 21107   UPR194         -17,63   201809          ESPAÑA
# 3224   UPR1205  -1,933444e+05   201805          ESPAÑA
# 17956  UPR1863      -716350,7   201805          ESPAÑA
# 10246  UPR2182      -169002,2   201707          ESPAÑA
# 6517   UPR2331       82503,13   201702          ESPAÑA
# 8886    UPR304       201877,7   201705          ESPAÑA
# 8514   UPR1851       767257,9   201705        PORTUGAL
# 6330   UPR1864        2250524   201702          ESPAÑA
# 4300   UPR2103  -4,929911e+05   201809          ESPAÑA

# %%
df_merged[df_merged['ID_AREA_SISTEMA'].isna()].head(5)
# Out:
# Empty DataFrame
# Columns: [ID_CONCEPTO_CTRL, ID_GRUPO_EMPRESARIAL, ID_TECNOLOGIA, ID_UNIDAD, ID_UPR, VALOR, VERSION, ID_AREA_SISTEMA]
# Index: []

# %% [markdown]
# And finally, reorder de columns to the same order we are already used to

# %%
df_merged = df_merged[['VERSION','ID_UPR','ID_TECNOLOGIA','ID_GRUPO_EMPRESARIAL','ID_AREA_SISTEMA','ID_CONCEPTO_CTRL','VALOR']]
df_merged.reset_index()
df_merged.sample(5)
# Out:
#        VERSION   ID_UPR ID_TECNOLOGIA ID_GRUPO_EMPRESARIAL ID_AREA_SISTEMA  \
# 2755    201803  UPR1207            EB             EMPRESA1          ESPAÑA
# 21472   201809   UPR418            EB             EMPRESA1          ESPAÑA
# 2386    201801   UPR194            HN             EMPRESA1          ESPAÑA
# 14817   201801   UPR162            GN             EMPRESA1          ESPAÑA
# 6770    201702    UPR74            HN             EMPRESA1          ESPAÑA
#
#          ID_CONCEPTO_CTRL          VALOR
# 2755            CANON HID  -3,809874e+04
# 21472  D. Medida Contador       -3109097
# 2386            PEAJE GEN  -5,683775e+04
# 14817               Banda        5464730
# 6770            M. Diario        7238959

# %% [markdown]
# At this point, I will save the current df "df_merged" for the future visualizatin part, this is the structure desired to represent the Integral Margin of the different power plants and so it is for the temporal evolution of every single one of them.
#
# The problem here seemed to be the data types... so first I tried to convert the column value to numeric directly
# with no success...
#
# The error got, suggested that I should convert the data type to floats but the lesson learnt here was that float type in pandas use dots insted of comma for float

# %%
df_merged.dtypes
# Out:
# VERSION                  int64
# ID_UPR                  object
# ID_TECNOLOGIA           object
# ID_GRUPO_EMPRESARIAL    object
# ID_AREA_SISTEMA         object
# ID_CONCEPTO_CTRL        object
# VALOR                   object
# dtype: object

# %%
df_merged['VALOR'].str.replace(',','.').sample(10)
# Out:
# 16797          -6201.8
# 9023         341565547
# 6308         -154359.7
# 2121      8.881526e+02
# 12060            -8.64
# 16967          1603866
# 23474        -14621057
# 1951     -2.084532e+05
# 2253     -4.318225e+03
# 14001         18915664
# Name: VALOR, dtype: object

# %%
#pd.to_numeric(df_merged['VALOR'])
df_merged['VALOR'] = pd.to_numeric((df_merged['VALOR'].str.replace(',','.')),errors='coerce').fillna(0).astype(np.int64)
df_merged.sample(10)
# Out:
#        VERSION   ID_UPR ID_TECNOLOGIA ID_GRUPO_EMPRESARIAL ID_AREA_SISTEMA  \
# 12166   201710  UPR1314            BP             EMPRESA1          ESPAÑA
# 2191    201712  UPR2182            GN             EMPRESA1          ESPAÑA
# 14520   201712   UPR300            GN             EMPRESA1          ESPAÑA
# 11596   201709  UPR1860            CI             EMPRESA1          ESPAÑA
# 3825    201807  UPR2331            EB             EMPRESA1          ESPAÑA
# 1197    201707  UPR1860            CI             EMPRESA1          ESPAÑA
# 648     201704  UPR1863            CI             EMPRESA1          ESPAÑA
# 17949   201805  UPR1862            CI             EMPRESA1          ESPAÑA
# 2056    201711   UPR303            HN             EMPRESA1          ESPAÑA
# 16754   201803  UPR2343            LN             EMPRESA1          ESPAÑA
#
#          ID_CONCEPTO_CTRL    VALOR
# 12166          G. Desvios   -55432
# 2191                  ATR  -337533
# 14520       R. Secundaria  -841391
# 11596  D. Medida Contador  -995916
# 3825      CANON_CONCESION    99356
# 1197       TASAS_MEDIOAMB  -121233
# 648                  UREA     -266
# 17949     M. Intradiarios  3153164
# 2056       TASAS_MEDIOAMB    -9027
# 16754  D. Medida Contador  -411144

# %%
df_merged['VALOR'].sum()
# Out:
# 176045148550

# %%
#df_merged.to_csv?
df_merged.to_csv(Path.cwd() / 'Outputs' / 'INTEGRATED_MARGIN.csv', sep= ';',index=False)

# %% [markdown]
# Now I proceed to unstack or pivot the table to get the suitable structure for modeling
# During this procedure, I've faced multiple problems so here I brievely describe the process:
#
# 1. First attempts ended on multiple errors such as "Length of passed values is 15227, index implies 1" , "index contains duplicate entries,cannot reshape"
# 2. It seemed clear that in any moment of the dropping unused columns, I created a duplicity on a register so first thing requieres was to do a group by
# 3. After done, I reseted the index for setting free all the columns
# 4. I used the pandas fuction "pivot_table" instead the method .pivot due to the hability of the first one to summing all the values generated with duplicities during the process of resizing.
# 5. Once pivoted, indexes and headers were a problematic segmentation so I dropped it out and create a new header.

# %%
df_pivoted = df_merged[['VERSION','ID_UPR','ID_TECNOLOGIA','ID_CONCEPTO_CTRL','VALOR']]
df_pivoted.shape
# Out:
# (15227, 5)

# %%
df_pivoted2 =df_pivoted.groupby(['VERSION','ID_UPR','ID_TECNOLOGIA','ID_CONCEPTO_CTRL']).sum()
print(df_pivoted2.shape)
print(df_pivoted2.columns)
df_pivoted2.sample(5)
# Out:
# (15122, 1)
# Index(['VALOR'], dtype='object')
#                                                    VALOR
# VERSION ID_UPR  ID_TECNOLOGIA ID_CONCEPTO_CTRL
# 201711  UPR2182 GN            Banda              3861053
# 201712  UPR2414 BP            Bilateral        -10535604
# 201807  UPR417  EB            M. Intradiarios   -3268295
# 201808  UPR300  GN            TASAS_MEDIOAMB           0
# 201811  UPR162  GN            Terciaria          3652391

# %%
df_pivoted2= df_pivoted2.reset_index()
df_pivoted2.head(5)
# Out:
#    VERSION  ID_UPR ID_TECNOLOGIA    ID_CONCEPTO_CTRL     VALOR
# 0   201701  UPR115            NC           Bilateral  81778497
# 1   201701  UPR115            NC        CANON_NC_EST  -2543929
# 2   201701  UPR115            NC   COSTE_COMBUSTIBLE  -1875378
# 3   201701  UPR115            NC  D. Medida Contador     -7853
# 4   201701  UPR115            NC      IMPUESTO ELECT  -3190970

# %%
df_pivoted2.columns
# Out:
# Index(['VERSION', 'ID_UPR', 'ID_TECNOLOGIA', 'ID_CONCEPTO_CTRL', 'VALOR'], dtype='object')

# %%
df_pivoted3 = df_pivoted2.pivot_table( 
                          values=['VALOR'], 
                          index=['VERSION', 'ID_UPR', 'ID_TECNOLOGIA'],
                          columns=['ID_CONCEPTO_CTRL'], 
                          aggfunc=np.sum)
df_pivoted3.sample(10)
# Out:
#                                        VALOR                                  \
# ID_CONCEPTO_CTRL              A. No Cobrados AMONIACO        ATR      Ajuste
# VERSION ID_UPR  ID_TECNOLOGIA
# 201712  UPR2415 BP                       NaN      NaN        NaN  -3586949.0
# 201708  UPR2415 BP                       NaN      NaN        NaN  -6111375.0
# 201706  UPR417  EB                       NaN      NaN        NaN         NaN
# 201708  UPR1206 BX                       NaN      NaN        NaN         NaN
# 201804  UPR418  EB                       NaN      NaN        NaN -31879575.0
# 201704  UPR1850 GN                       NaN      NaN  -232869.0         NaN
# 201805  UPR2331 EB                       NaN      NaN        NaN  -1742889.0
# 201703  UPR1851 GN                       NaN      NaN -1217682.0         NaN
# 201804  UPR300  GN                       NaN      NaN  1105713.0         NaN
# 201810  UPR1751 BP                       NaN      NaN        NaN  -8363216.0
#
#                                                                         \
# ID_CONCEPTO_CTRL              BONO_SOCIAL_PEGO      Banda    Bilateral
# VERSION ID_UPR  ID_TECNOLOGIA
# 201712  UPR2415 BP                         NaN   167366.0          NaN
# 201708  UPR2415 BP                         NaN        NaN          NaN
# 201706  UPR417  EB                         NaN        NaN          NaN
# 201708  UPR1206 BX                         NaN        NaN          NaN
# 201804  UPR418  EB                         NaN  5277166.0  919729782.0
# 201704  UPR1850 GN                   -208453.0  1139583.0          NaN
# 201805  UPR2331 EB                         NaN   365241.0   28429124.0
# 201703  UPR1851 GN                   -208453.0  1520302.0          NaN
# 201804  UPR300  GN                         NaN        NaN          NaN
# 201810  UPR1751 BP                         NaN        NaN   -2454610.0
#
#                                                                   ...  \
# ID_CONCEPTO_CTRL              CALIZAS  CANON HID CANON_CONCESION  ...
# VERSION ID_UPR  ID_TECNOLOGIA                                     ...
# 201712  UPR2415 BP                NaN        NaN             NaN  ...
# 201708  UPR2415 BP                NaN        NaN             NaN  ...
# 201706  UPR417  EB                NaN   -11843.0             NaN  ...
# 201708  UPR1206 BX                NaN        NaN             NaN  ...
# 201804  UPR418  EB                NaN -3987281.0      -2532808.0  ...
# 201704  UPR1850 GN                NaN        NaN             NaN  ...
# 201805  UPR2331 EB                NaN  -104684.0        -17739.0  ...
# 201703  UPR1851 GN                NaN        NaN             NaN  ...
# 201804  UPR300  GN                NaN        NaN             NaN  ...
# 201810  UPR1751 BP                NaN        NaN             NaN  ...
#
#                                                                              \
# ID_CONCEPTO_CTRL              Redespachos Res. Pot. Adicional S. Regulacion
# VERSION ID_UPR  ID_TECNOLOGIA
# 201712  UPR2415 BP                  -15.0                 NaN           NaN
# 201708  UPR2415 BP                21566.0                 NaN           NaN
# 201706  UPR417  EB                    NaN                 NaN           NaN
# 201708  UPR1206 BX                    NaN                 NaN           NaN
# 201804  UPR418  EB                    NaN                 NaN           NaN
# 201704  UPR1850 GN                -2691.0                 NaN      -22816.0
# 201805  UPR2331 EB                    NaN                 NaN           NaN
# 201703  UPR1851 GN                    NaN                 NaN      -76129.0
# 201804  UPR300  GN                    NaN                 NaN           NaN
# 201810  UPR1751 BP              -119044.0                 NaN           NaN
#
#                                                                     \
# ID_CONCEPTO_CTRL              S. Res. Pot. Adicional SERV_GEST_RES
# VERSION ID_UPR  ID_TECNOLOGIA
# 201712  UPR2415 BP                           -5925.0           NaN
# 201708  UPR2415 BP                            -254.0           NaN
# 201706  UPR417  EB                             -14.0           NaN
# 201708  UPR1206 BX                               NaN           NaN
# 201804  UPR418  EB                           -2584.0           NaN
# 201704  UPR1850 GN                               NaN           NaN
# 201805  UPR2331 EB                           -8545.0           NaN
# 201703  UPR1851 GN                               NaN           NaN
# 201804  UPR300  GN                            -610.0           NaN
# 201810  UPR1751 BP                              -3.0           NaN
#
#                                                                           \
# ID_CONCEPTO_CTRL              TASAS_MEDIOAMB TASA_ARAGON  Terciaria UREA
# VERSION ID_UPR  ID_TECNOLOGIA
# 201712  UPR2415 BP                       NaN         NaN  9345873.0  NaN
# 201708  UPR2415 BP                       NaN         NaN  -306694.0  NaN
# 201706  UPR417  EB                       NaN     23850.0    12944.0  NaN
# 201708  UPR1206 BX                  104386.0         NaN        NaN  NaN
# 201804  UPR418  EB                       NaN   -850014.0  4394852.0  NaN
# 201704  UPR1850 GN                       NaN         NaN  -272625.0  NaN
# 201805  UPR2331 EB                 -160804.0         NaN  5402263.0  NaN
# 201703  UPR1851 GN                       NaN         NaN  -405140.0  NaN
# 201804  UPR300  GN                   -7026.0         NaN        NaN  NaN
# 201810  UPR1751 BP                       NaN         NaN  -490293.0  NaN
#
#
# ID_CONCEPTO_CTRL                    VCF
# VERSION ID_UPR  ID_TECNOLOGIA
# 201712  UPR2415 BP               -555.0
# 201708  UPR2415 BP                  NaN
# 201706  UPR417  EB                  NaN
# 201708  UPR1206 BX                  NaN
# 201804  UPR418  EB            -119583.0
# 201704  UPR1850 GN                  NaN
# 201805  UPR2331 EB               1531.0
# 201703  UPR1851 GN                  NaN
# 201804  UPR300  GN                  NaN
# 201810  UPR1751 BP                  NaN
#
# [10 rows x 42 columns]

# %%
df_pivoted3.columns = df_pivoted3.columns.droplevel()
df_modelize= df_pivoted3.reset_index()
df_modelize.head(10)
# Out:
# ID_CONCEPTO_CTRL  VERSION   ID_UPR ID_TECNOLOGIA  A. No Cobrados  AMONIACO  \
# 0                  201701   UPR115            NC             NaN       NaN
# 1                  201701   UPR116            NC             NaN       NaN
# 2                  201701  UPR1198            NC             NaN       NaN
# 3                  201701  UPR1205            EB             NaN       NaN
# 4                  201701  UPR1206            BX             NaN       NaN
# 5                  201701  UPR1207            EB             NaN       NaN
# 6                  201701  UPR1314            BP             NaN       NaN
# 7                  201701  UPR1315            BP             NaN       NaN
# 8                  201701   UPR160            GN       -994654.0       NaN
# 9                  201701   UPR162            GN       -418200.0       NaN
#
# ID_CONCEPTO_CTRL       ATR    Ajuste  BONO_SOCIAL_PEGO      Banda   Bilateral  \
# 0                      NaN       NaN               NaN        NaN  81778497.0
# 1                      NaN       NaN               NaN        NaN  68455391.0
# 2                      NaN       NaN               NaN        NaN         NaN
# 3                      NaN -124366.0               NaN        NaN   1578792.0
# 4                      NaN   -9972.0               NaN        NaN         NaN
# 5                      NaN -198314.0               NaN    15066.0     59653.0
# 6                      NaN -429377.0               NaN        NaN   -118383.0
# 7                      NaN -506708.0               NaN     2001.0         NaN
# 8                -938689.0       NaN               NaN  1045907.0         NaN
# 9                -507356.0       NaN               NaN   957825.0         NaN
#
# ID_CONCEPTO_CTRL  ...  Redespachos  Res. Pot. Adicional  S. Regulacion  \
# 0                 ...          NaN                  NaN            NaN
# 1                 ...          NaN                  NaN            NaN
# 2                 ...          NaN                  NaN            NaN
# 3                 ...          NaN                  NaN            NaN
# 4                 ...          NaN                  NaN            NaN
# 5                 ...          NaN                  NaN            NaN
# 6                 ...      -8556.0                  NaN            NaN
# 7                 ...       1146.0                  NaN            NaN
# 8                 ...      47854.0              51355.0            NaN
# 9                 ...     745956.0             579221.0            NaN
#
# ID_CONCEPTO_CTRL  S. Res. Pot. Adicional  SERV_GEST_RES  TASAS_MEDIOAMB  \
# 0                                  -36.0      -197055.0             NaN
# 1                                    NaN      -308245.0             NaN
# 2                                 -192.0            NaN             NaN
# 3                                 -455.0            NaN        -33711.0
# 4                                   -7.0            NaN        -16346.0
# 5                                 -807.0            NaN         -1528.0
# 6                                  -39.0            NaN             NaN
# 7                                 -397.0            NaN             NaN
# 8                                -2223.0            NaN             NaN
# 9                                 -316.0            NaN             NaN
#
# ID_CONCEPTO_CTRL  TASA_ARAGON  Terciaria  UREA      VCF
# 0                         NaN        NaN   NaN      NaN
# 1                         NaN        NaN   NaN      NaN
# 2                         NaN        NaN   NaN      NaN
# 3                         NaN    55144.0   NaN      NaN
# 4                         NaN        NaN   NaN      NaN
# 5                         NaN   225821.0   NaN    999.0
# 6                         NaN   -24031.0   NaN      NaN
# 7                         NaN   441646.0   NaN   -162.0
# 8                         NaN   251416.0   NaN -14892.0
# 9                         NaN   573346.0   NaN -17674.0
#
# [10 rows x 45 columns]

# %% [markdown]
# Finally, we incorporate now the last column of data that we are gonna implement to the model, the power column from the second
# dataframe that we got in the liquidations R process

# %%
df_power = pd.read_csv(Path.cwd() / 'Outputs' / 'LIQUIDACIONES_MWH.csv' , sep = ';', header = 0 , encoding = "ISO-8859-1",decimal=',')
print(df_power.describe())
df_power.sample(5)
# Out:
#              VERSION         VALOR
# count   13048.000000  1.304800e+04
# mean   201754.106913  4.498754e+05
# std        49.951242  2.031215e+06
# min    201701.000000 -5.489374e+06
# 25%    201706.000000 -9.301933e+03
# 50%    201712.000000  2.225860e+03
# 75%    201806.000000  8.903905e+04
# max    201812.000000  3.518217e+07
#        VERSION   ID_UPR ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA  \
# 1363    201703  UPR1861             EMPRESA1            CI
# 3760    201707  UPR2491             EMPRESA2            NC
# 7357    201801    UPR78             EMPRESA2            NC
# 5505    201710   UPR366             EMPRESA2            BP
# 10873   201808  UPR2342             EMPRESA1            LN
#
#          ID_CONCEPTO_CTRL ID_UNIDAD        VALOR
# 1363        R. Secundaria       MWH     2682.859
# 3760   D. Medida Contador       MWH    -4800.639
# 7357            Bilateral       MWH  9954000.000
# 5505               Ajuste       MWH   -88537.200
# 10873           Bilateral       MWH  3255095.000

# %% [markdown]
# I apply the same filters that I did in the previous dfs
#
# And eventually a group by just in case we have the same problem than before

# %%
df_power = df_power[df_power['ID_GRUPO_EMPRESARIAL'] == 'EMPRESA1']
print(df_power.describe())
# Out:
#              VERSION         VALOR
# count    6417.000000  6.417000e+03
# mean   201755.352189  4.508979e+05
# std        50.180305  2.115280e+06
# min    201701.000000 -3.789073e+06
# 25%    201706.000000 -1.387000e+04
# 50%    201712.000000  2.163250e+02
# 75%    201807.000000  5.869300e+04
# max    201812.000000  3.256008e+07

# %%
df_power = df_power[['VERSION','ID_UPR','ID_TECNOLOGIA','VALOR']]
df_power= df_power.groupby(['VERSION','ID_UPR','ID_TECNOLOGIA']).sum().reset_index()
print(df_power.describe())
# Out:
#              VERSION         VALOR
# count    1024.000000  1.024000e+03
# mean   201755.424805  2.825598e+06
# std        50.143803  4.930549e+06
# min    201701.000000 -3.789073e+06
# 25%    201706.000000  2.363667e+04
# 50%    201712.000000  5.563538e+05
# 75%    201806.000000  3.699485e+06
# max    201812.000000  3.262049e+07

# %%
df_power.describe()
# Out:
#              VERSION         VALOR
# count    1024.000000  1.024000e+03
# mean   201755.424805  2.825598e+06
# std        50.143803  4.930549e+06
# min    201701.000000 -3.789073e+06
# 25%    201706.000000  2.363667e+04
# 50%    201712.000000  5.563538e+05
# 75%    201806.000000  3.699485e+06
# max    201812.000000  3.262049e+07

# %%
df_modelize = pd.merge(df_modelize, df_power, on=['VERSION','ID_UPR','ID_TECNOLOGIA'], how='left')
df_modelize = df_modelize.rename(columns={'VALOR': 'POWER_MWH'})
df_modelize.sample(10)
# Out:
#      VERSION   ID_UPR ID_TECNOLOGIA  A. No Cobrados  AMONIACO        ATR  \
# 906   201809   UPR304            HN             NaN       NaN        NaN
# 19    201701  UPR1863            CI             NaN       NaN        NaN
# 933   201810   UPR194            HN             NaN       NaN        NaN
# 619   201803   UPR160            GN       1552619.0       NaN  -327355.0
# 242   201706  UPR2103            EB             NaN       NaN        NaN
# 147   201704  UPR1851            GN             NaN       NaN  -188983.0
# 521   201712   UPR418            EB             NaN       NaN        NaN
# 798   201807  UPR1850            GN             NaN       NaN -2755574.0
# 696   201804    UPR77            NC             NaN       NaN        NaN
# 501   201712  UPR1863            CI       1680134.0       NaN        NaN
#
#          Ajuste  BONO_SOCIAL_PEGO       Banda    Bilateral  ...  \
# 906 -30302705.0               NaN   4353773.0   48547240.0  ...
# 19    -665273.0               NaN    507087.0          NaN  ...
# 933  -2979839.0               NaN   4676164.0   45649355.0  ...
# 619         NaN               NaN  41000861.0          NaN  ...
# 242  -9973601.0               NaN         NaN   22620640.0  ...
# 147         NaN         -208453.0   3647717.0          NaN  ...
# 521 -22006169.0               NaN   1617993.0  221521612.0  ...
# 798         NaN               0.0  11198787.0          NaN  ...
# 696         NaN               NaN         NaN  315371005.0  ...
# 501         NaN               NaN  12846378.0   26215189.0  ...
#
#      Res. Pot. Adicional  S. Regulacion  S. Res. Pot. Adicional  \
# 906            3326822.0            NaN                -12510.0
# 19                   NaN            NaN                  -385.0
# 933             582666.0            NaN                  -892.0
# 619                  NaN            NaN                 -1242.0
# 242                  NaN            NaN                   -59.0
# 147                  NaN       -13461.0                     NaN
# 521                  NaN            NaN                  -747.0
# 798                  NaN      -453631.0                     NaN
# 696                  NaN            NaN                  -119.0
# 501                  NaN            NaN                  -153.0
#
#      SERV_GEST_RES  TASAS_MEDIOAMB  TASA_ARAGON   Terciaria    UREA  \
# 906            NaN             0.0          NaN   -379058.0     NaN
# 19             NaN        -16965.0          NaN     60666.0     NaN
# 933            NaN             0.0          NaN    256886.0     NaN
# 619            NaN             NaN          NaN   6516341.0     NaN
# 242            NaN       -342718.0          NaN   2788893.0     NaN
# 147            NaN             NaN          NaN   -347280.0     NaN
# 521            NaN             NaN    -563690.0  10071687.0     NaN
# 798            NaN             NaN          NaN -16619612.0     NaN
# 696         3328.0      -2061993.0          NaN         NaN     NaN
# 501            NaN        -12093.0          NaN    433606.0 -2098.0
#
#            VCF    POWER_MWH
# 906   -26216.0  6112505.350
# 19    -24716.0   356606.660
# 933      -92.0  5758031.670
# 619 -1031038.0  2870328.030
# 242        NaN   250413.622
# 147        NaN  1281399.496
# 521   -52571.0  3515170.508
# 798        NaN  6580730.350
# 696        NaN  8254901.674
# 501   -29388.0  4719742.070
#
# [10 rows x 46 columns]

# %%
df_modelize.to_csv(Path.cwd() / 'Outputs' / 'DF_MODELIZE.csv', sep= ';',decimal=',',index=False)

# %%
To_be_deleted =['df1',
                'df_aux',
                'df_merged',
                'dfTotal',
                'df_pivoted',
                'df_pivoted2',
                'df_pivoted3',
                'path_list',
                'inputpath',
                'inputpath1']
To_be_deleted
# Out:
# ['df1',
#  'df_aux',
#  'df_merged',
#  'dfTotal',
#  'df_pivoted',
#  'df_pivoted2',
#  'df_pivoted3',
#  'path_list',
#  'inputpath',
#  'inputpath1']

# %%
for item in To_be_deleted:
    try:
        del item
    except:
        pass
