# %% [markdown]
# # Python TFM Section

# %% [markdown]
# ## Data Processing
#
# On this section of the TFM it will be done all the preparation needed for the model:
#
# 1. Import all the .csv created on the R section to unify them
# 2. Set up a unique data frame where we will have all the variables and information required to the regression model
# 3. Unstack the structure for making it more suitable to be used on a model

# %%
#Import the common used libraries for df treatment and fast visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
#!conda install --yes pathlib
#$ python -m pip install pathlib

# %%
# After being instaled, import pathlib for having the relative path in the easiest way possible
from pathlib import Path

# %%
print(Path.cwd())
# Out:
# C:\Users\ES71531200G\Desktop\Data Science\00.TFM

# %%
#Defining path to files from the imports folder
# %pwd

file1 = "COSTES_E4E_EUROS.csv"
file2 = "LIQUIDACIONES_EUROS.csv"
file3 = "NUCLEAR_WASTES_EUROS.csv"

file5 = "LIQUIDACIONES_MWH.csv"

File_list = [file1, file2, file3]
del(file1,file2,file3)


File_list
# Out:
# ['COSTES_E4E_EUROS.csv', 'LIQUIDACIONES_EUROS.csv', 'NUCLEAR_WASTES_EUROS.csv']

# %%
#command to check all the variables created this far
# %whos
# Out:
# Variable    Type      Data/Info
# -------------------------------
# File_list   list      n=3
# Path        type      <class 'pathlib.Path'>
# file5       str       LIQUIDACIONES_MWH.csv
# np          module    <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd          module    <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt         module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>

# %% [markdown]
# Importing directly with the read_csv function retrieves an error due to the encoding used by R during the exportation
# The parametres encoding and sep solve the probem

# %%
inputpath1 = Path.cwd() / 'Outputs' / 'COSTES_E4E_EUROS.csv' 
df1 = pd.read_csv(inputpath1, sep = ';', header = 0 , encoding = "ISO-8859-1")

# %% [markdown]
# I create a df with the same columnames and data types but no rows for using it as the initial frame to append everything alltogheter.

# %%
dfTotal = df1[0:0]
del(df1)
dfTotal
# Out:
# Empty DataFrame
# Columns: [VERSION, ID_UPR, ID_TECNOLOGIA, ID_GRUPO_EMPRESARIAL, ID_AREA_SISTEMA, ID_CONCEPTO_CTRL, VALOR, ID_UNIDAD]
# Index: []

# %%
path_list = []
for file in File_list:
    inputpath = Path.cwd() / 'Outputs' / file
    print (inputpath)
    df1 = pd.read_csv(inputpath, sep = ';', header = 0 , encoding = "ISO-8859-1")
    dfTotal = dfTotal.append(df1)
# Out:
# C:\Users\ES71531200G\Desktop\Data Science\00.TFM\Outputs\COSTES_E4E_EUROS.csv
# C:\Users\ES71531200G\Desktop\Data Science\00.TFM\Outputs\LIQUIDACIONES_EUROS.csv
# C:\Users\ES71531200G\Desktop\Data Science\00.TFM\Outputs\NUCLEAR_WASTES_EUROS.csv
# C:\Users\ES71531200G\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %% [markdown]
# The process comes back a warning saying that one column is nmissing in at least one section, so we explore the data to see what's happening

# %%
dfTotal.sample(20)
# Out:
#       ID_AREA_SISTEMA           ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL  \
# 6016              NaN            M. Intradiarios             EMPRESA2
# 17507             NaN             G. Potencia LP             EMPRESA1
# 3807           ESPAÑA              CENTIMO_VERDE             EMPRESA1
# 16028             NaN  I. G. Desvíos y Terciaria             EMPRESA1
# 5413              NaN     S. Res. Pot. Adicional             EMPRESA1
# 1231           ESPAÑA                      OTROS             EMPRESA1
# 3315           ESPAÑA   RELIQ_CANON_NC_CATALUÃA             EMPRESA1
# 3600              NaN            M. Intradiarios             EMPRESA1
# 11552             NaN                        VCF             EMPRESA2
# 15778             NaN  I. G. Desvíos y Terciaria             EMPRESA3
# 912            ESPAÑA                      OTROS             EMPRESA1
# 2283              NaN                  M. Diario             EMPRESA3
# 16858             NaN              R. Secundaria             EMPRESA2
# 9756              NaN  I. G. Desvíos y Terciaria             EMPRESA2
# 3919              NaN         D. Medida Contador             EMPRESA1
# 3081           ESPAÑA                        ATR             EMPRESA1
# 390            ESPAÑA          COSTE_COMBUSTIBLE             EMPRESA1
# 17002             NaN                  Bilateral             EMPRESA1
# 5124              NaN                  Terciaria             EMPRESA1
# 1774           ESPAÑA             TASAS_MEDIOAMB             EMPRESA1
#
#       ID_TECNOLOGIA ID_UNIDAD   ID_UPR          VALOR  VERSION
# 6016             NC     EUROS   UPR295      -261919,8   201708
# 17507            GN     EUROS  UPR1864       32702929   201811
# 3807             HN     EUROS   UPR304  -2,013255e+04   201807
# 16028            BP     EUROS  UPR2142      -45129,79   201809
# 5413             NC     EUROS  UPR1198        -70,555   201708
# 1231             LN     EUROS  UPR2342  -1,043785e+03   201707
# 3315             NC     EUROS  UPR2622   0,000000e+00   201805
# 3600             LN     EUROS  UPR2342       -3248840   201705
# 11552            BX     EUROS  UPR2262        3156733   201803
# 15778            GN     EUROS  UPR1714      -150076,7   201809
# 912              HN     EUROS    UPR74  -2,781589e+02   201705
# 2283             EB     EUROS  UPR2600        9255839   201703
# 16858            GN     EUROS  UPR2269       -1206703   201810
# 9756             BP     EUROS  UPR1762       -1376160   201801
# 3919             BP     EUROS  UPR1315      -27612,82   201706
# 3081             GN     EUROS   UPR300   1,105713e+06   201804
# 390              GN     EUROS   UPR160  -2,403443e+06   201703
# 17002            NC     EUROS  UPR2622     1531990099   201810
# 5124             EB     EUROS  UPR2331       834984,1   201707
# 1774             EB     EUROS  UPR2331   1,266354e+05   201710

# %% [markdown]
# ### NaN replacement

# %% [markdown]
# We obserb that the file "LIQUIDACIONES_EUROS" doesn't have the column ID_AREA_SISTEMA.
# To overpass this situations, I proceed to replace all the NaNs with the right values through the selection of the unique tuples
# [ID_AREA_SISTEMA - ID_UPR].

# %%
df_aux = dfTotal[['ID_AREA_SISTEMA', 'ID_UPR']].dropna().drop_duplicates()
df_aux.sample(10)
# Out:
#     ID_AREA_SISTEMA   ID_UPR
# 19           ESPAÑA  UPR1315
# 80           ESPAÑA   UPR194
# 75           ESPAÑA  UPR1864
# 102          ESPAÑA  UPR2341
# 12           ESPAÑA  UPR1206
# 51           ESPAÑA  UPR1860
# 137          ESPAÑA   UPR300
# 98           ESPAÑA  UPR2331
# 29           ESPAÑA  UPR1661
# 48         PORTUGAL  UPR1851

# %% [markdown]
# And now I will replace the values using a left join with pandas

# %%
df_merged = pd.merge(dfTotal, df_aux, on='ID_UPR', how='left')
df_merged.sample(10)
df_merged.columns
# Out:
# Index(['ID_AREA_SISTEMA_x', 'ID_CONCEPTO_CTRL', 'ID_GRUPO_EMPRESARIAL',
#        'ID_TECNOLOGIA', 'ID_UNIDAD', 'ID_UPR', 'VALOR', 'VERSION',
#        'ID_AREA_SISTEMA_y'],
#       dtype='object')

# %%
df_merged = df_merged.rename(columns={'ID_AREA_SISTEMA_y': 'ID_AREA_SISTEMA'})
df_merged = df_merged.drop(columns="ID_AREA_SISTEMA_x")
print(df_merged.columns)
df_merged.sample(10)
# Out:
# Index(['ID_CONCEPTO_CTRL', 'ID_GRUPO_EMPRESARIAL', 'ID_TECNOLOGIA',
#        'ID_UNIDAD', 'ID_UPR', 'VALOR', 'VERSION', 'ID_AREA_SISTEMA'],
#       dtype='object')
#              ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA ID_UNIDAD  \
# 10726      D. Medida Contador             EMPRESA1            CI     EUROS
# 3447                     UREA             EMPRESA1            CI     EUROS
# 4071                PEAJE GEN             EMPRESA1            BX     EUROS
# 21801                   Banda             EMPRESA3            GN     EUROS
# 1783                 AMONIACO             EMPRESA1            LN     EUROS
# 1875           IMPUESTO ELECT             EMPRESA1            BP     EUROS
# 13786               M. Diario             EMPRESA2            HN     EUROS
# 1214           IMPUESTO ELECT             EMPRESA1            EB     EUROS
# 17397               M. Diario             EMPRESA1            NC     EUROS
# 12646  S. Res. Pot. Adicional             EMPRESA2            NC     EUROS
#
#         ID_UPR          VALOR  VERSION ID_AREA_SISTEMA
# 10726  UPR1861       37918,22   201708          ESPAÑA
# 3447   UPR1860  -3,200063e+04   201806          ESPAÑA
# 4071    UPR726  -2,069280e+01   201808          ESPAÑA
# 21801    UPR21       152325,3   201810             NaN
# 1783   UPR2342  -7,255110e+03   201710          ESPAÑA
# 1875   UPR1315   6,032868e+01   201711          ESPAÑA
# 13786  UPR1310      195743857   201712             NaN
# 1214   UPR2331  -6,176099e+04   201707          ESPAÑA
# 17397  UPR2491        9643711   201804          ESPAÑA
# 12646  UPR2622       -298,045   201710          ESPAÑA

# %%
df_merged = df_merged[df_merged['ID_GRUPO_EMPRESARIAL'] == 'EMPRESA1']
df_merged.sample(10)
# Out:
#          ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA ID_UNIDAD  \
# 17275          G. Desvios             EMPRESA1            BP     EUROS
# 10458     M. Intradiarios             EMPRESA1            NC     EUROS
# 12261           M. Diario             EMPRESA1            GN     EUROS
# 6418        R. Secundaria             EMPRESA1            LN     EUROS
# 18574      G. Potencia LP             EMPRESA1            CI     EUROS
# 10368  D. Medida Contador             EMPRESA1            EB     EUROS
# 18874              Ajuste             EMPRESA1            BP     EUROS
# 11481       R. Secundaria             EMPRESA1            GN     EUROS
# 23566       SERV_GEST_RES             EMPRESA1            NC     EUROS
# 3197    COSTE_COMBUSTIBLE             EMPRESA1            GN     EUROS
#
#         ID_UPR          VALOR  VERSION ID_AREA_SISTEMA
# 17275  UPR2141      -63365,55   201804             NaN
# 10458   UPR116      -179416,7   201708          ESPAÑA
# 12261  UPR1851      188593618   201710        PORTUGAL
# 6418   UPR2341       99772,74   201702          ESPAÑA
# 18574  UPR1860        9053636   201806          ESPAÑA
# 10368   UPR417      -98372,01   201707          ESPAÑA
# 18874  UPR2414       -5750324   201806          ESPAÑA
# 11481  UPR1851        3524009   201709        PORTUGAL
# 23566    UPR77   -1807981,693   201807          ESPAÑA
# 3197   UPR1850  -1,432440e+03   201805        PORTUGAL

# %%
df_merged[df_merged['ID_AREA_SISTEMA'].isna()].head(5)
# Out:
#             ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA ID_UNIDAD  \
# 5079      D. Medida Contador             EMPRESA1            NC     EUROS
# 5080  S. Res. Pot. Adicional             EMPRESA1            NC     EUROS
# 5239                  Ajuste             EMPRESA1            BP     EUROS
# 5240               Bilateral             EMPRESA1            BP     EUROS
# 5241      D. Medida Contador             EMPRESA1            BP     EUROS
#
#        ID_UPR      VALOR  VERSION ID_AREA_SISTEMA
# 5079  UPR1198  -35305,63   201701             NaN
# 5080  UPR1198     -192,8   201701             NaN
# 5239  UPR1751  -374890,6   201701             NaN
# 5240  UPR1751  -213155,6   201701             NaN
# 5241  UPR1751  -22453,97   201701             NaN

# %% [markdown]
# There are still NaN values, but thanks to our knowledge from the original data, we know that there are ONLY 2 UPRs with ID_AREA_SISTEMA = 'PORTUGAL', what means that every NaN value right now should be equal to ESPAÑA, so we replace now all the NANs

# %%
df_merged = df_merged.fillna('ESPAÑA')
df_merged.sample(10)
# Out:
#                ID_CONCEPTO_CTRL ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA ID_UNIDAD  \
# 21658                     Banda             EMPRESA1            GN     EUROS
# 3619   RELIQ_CANON_NC_CATALUÃA             EMPRESA1            NC     EUROS
# 3918                  PEAJE GEN             EMPRESA1            GN     EUROS
# 9410                      Banda             EMPRESA1            LN     EUROS
# 22555             R. Secundaria             EMPRESA1            CI     EUROS
# 3043             TASAS_MEDIOAMB             EMPRESA1            LN     EUROS
# 7091                      Banda             EMPRESA1            EB     EUROS
# 7501         D. Medida Contador             EMPRESA1            NC     EUROS
# 3904             IMPUESTO ELECT             EMPRESA1            CI     EUROS
# 20197                 M. Diario             EMPRESA1            CI     EUROS
#
#         ID_UPR          VALOR  VERSION ID_AREA_SISTEMA
# 21658  UPR1851       14607510   201810        PORTUGAL
# 3619    UPR116   0,000000e+00   201807          ESPAÑA
# 3918   UPR1851   0,000000e+00   201808        PORTUGAL
# 9410   UPR2341        2099372   201706          ESPAÑA
# 22555  UPR1863       -1261176   201811          ESPAÑA
# 3043   UPR2341   4,259270e+03   201804          ESPAÑA
# 7091   UPR2103       70365,07   201703          ESPAÑA
# 7501    UPR116       14894,21   201704          ESPAÑA
# 3904   UPR1662  -1,169843e+06   201808          ESPAÑA
# 20197  UPR1863      339687625   201808          ESPAÑA

# %%
df_merged[df_merged['ID_AREA_SISTEMA'].isna()].head(5)
# Out:
# Empty DataFrame
# Columns: [ID_CONCEPTO_CTRL, ID_GRUPO_EMPRESARIAL, ID_TECNOLOGIA, ID_UNIDAD, ID_UPR, VALOR, VERSION, ID_AREA_SISTEMA]
# Index: []

# %% [markdown]
# And finally, reorder de columns to the same order we are already used to

# %%
df_merged = df_merged[['VERSION','ID_UPR','ID_TECNOLOGIA','ID_GRUPO_EMPRESARIAL','ID_AREA_SISTEMA','ID_CONCEPTO_CTRL','VALOR']]
df_merged.reset_index()
df_merged.sample(5)
# Out:
#        VERSION   ID_UPR ID_TECNOLOGIA ID_GRUPO_EMPRESARIAL ID_AREA_SISTEMA  \
# 269     201702   UPR194            HN             EMPRESA1          ESPAÑA
# 18101   201805  UPR2414            BP             EMPRESA1          ESPAÑA
# 18560   201806  UPR1851            GN             EMPRESA1        PORTUGAL
# 12578   201710  UPR2414            BP             EMPRESA1          ESPAÑA
# 12759   201710   UPR418            EB             EMPRESA1          ESPAÑA
#
#              ID_CONCEPTO_CTRL          VALOR
# 269               LUBRICANTES  -7,675195e+00
# 18101  S. Res. Pot. Adicional        -645,63
# 18560                   Banda       13523918
# 12578             Redespachos      -18029,86
# 12759      D. Medida Contador      -389904,1

# %% [markdown]
# ### Solving the wrong data-type importation

# %% [markdown]
# At this point, I tryed to save the current df "df_merged" for the future visualizatin part, this is the structure desired to represent the Integral Margin of the different power plants and so it is for the temporal evolution of every single one of them.
#
# The problem here seemed to be the data types... so first I tried to convert the column value to numeric directly
# with no success...
#
# The error got, suggested that I should convert the data type to floats but the lesson learnt here was that float type in pandas use dots insted of comma for float

# %%
df_merged.dtypes
# Out:
# VERSION                  int64
# ID_UPR                  object
# ID_TECNOLOGIA           object
# ID_GRUPO_EMPRESARIAL    object
# ID_AREA_SISTEMA         object
# ID_CONCEPTO_CTRL        object
# VALOR                   object
# dtype: object

# %%
df_merged['VALOR'].str.replace(',','.').sample(10)
# Out:
# 3853      0.000000e+00
# 6779           -537.69
# 18270         11580.02
# 11836         -669.258
# 15450         -1925.23
# 7244          -3837804
# 10597         -1653637
# 15703          -109.74
# 4698      0.000000e+00
# 4376     -2.482806e+06
# Name: VALOR, dtype: object

# %%
df_merged['VALOR'] = pd.to_numeric((df_merged['VALOR'].str.replace(',','.')),errors='coerce').fillna(0).astype(np.int64)
df_merged.sample(10)
# Out:
#        VERSION   ID_UPR ID_TECNOLOGIA ID_GRUPO_EMPRESARIAL ID_AREA_SISTEMA  \
# 11313   201709   UPR160            GN             EMPRESA1          ESPAÑA
# 18895   201806  UPR2491            NC             EMPRESA1          ESPAÑA
# 2173    201712  UPR2344            EB             EMPRESA1          ESPAÑA
# 2845    201803  UPR2622            NC             EMPRESA1          ESPAÑA
# 22357   201811   UPR162            GN             EMPRESA1          ESPAÑA
# 13365   201711  UPR2331            EB             EMPRESA1          ESPAÑA
# 22500   201811  UPR1851            GN             EMPRESA1        PORTUGAL
# 12669   201710   UPR304            HN             EMPRESA1          ESPAÑA
# 10006   201707  UPR1863            CI             EMPRESA1          ESPAÑA
# 20991   201809   UPR194            HN             EMPRESA1          ESPAÑA
#
#                 ID_CONCEPTO_CTRL      VALOR
# 11313                 G. Desvios     442965
# 18895    M. Intradiario Continuo       8706
# 2173                 TASA_ARAGON      12681
# 2845                       OTROS     -13271
# 22357                  Terciaria    3652391
# 13365  I. G. Desvíos y Terciaria    -166229
# 22500              R. Secundaria    7208051
# 12669                     Ajuste   -1058067
# 10006                  M. Diario  147771076
# 20991            M. Intradiarios   28392252

# %% [markdown]
# Now, let's check if the total sum of the column "VALUE" is 175694686343 ( total sum we know it have to be from the original files summatory), and if so, it would mean that the comma-replacement solve the issue and we can export the file for the future visualization module.

# %%
df_merged['VALOR'].sum()
# Out:
# 175694686343

# %%
#df_merged.to_csv?
df_merged.to_csv(Path.cwd() / 'Outputs' / 'INTEGRATED_MARGIN.csv', sep= ';',index=False)

# %% [markdown]
# ### Pivoting/ Unstacking our df

# %% [markdown]
# Now I proceed to unstack or pivot the table to get the suitable structure for modeling
# During this procedure, I've faced multiple problems so here I brievely describe the process:
#
# 1. First attempts ended on multiple errors such as "Length of passed values is 15227, index implies 1" , "index contains duplicate entries,cannot reshape"
# 2. It seemed clear that in any moment of the dropping unused columns, I created a duplicity on a register so first thing requiered was to do a group by
# 3. After done, I reseted the index for setting free all the columns
# 4. I used the pandas fuction "pivot_table" instead the method .pivot due to the hability of the first one to summing all the values generated with duplicities during the process of resizing.
# 5. Once pivoted, indexes and headers were a problematic segmentation so I dropped it out and create a new header.

# %%
df_pivoted = df_merged[['VERSION','ID_UPR','ID_TECNOLOGIA','ID_CONCEPTO_CTRL','VALOR']]
df_pivoted.shape
# Out:
# (15117, 5)

# %%
df_pivoted2 =df_pivoted.groupby(['VERSION','ID_UPR','ID_TECNOLOGIA','ID_CONCEPTO_CTRL']).sum()
print(df_pivoted2.shape)
print(df_pivoted2.columns)
df_pivoted2.sample(5)
# Out:
# (15117, 1)
# Index(['VALOR'], dtype='object')
#                                                            VALOR
# VERSION ID_UPR  ID_TECNOLOGIA ID_CONCEPTO_CTRL
# 201703  UPR304  HN            D. Medida Contador         -136336
# 201706  UPR2331 EB            D. Medida Contador         -129675
# 201807  UPR418  EB            I. G. Desvíos y Terciaria -1036264
# 201810  UPR1205 EB            CANON HID                   -61818
# 201709  UPR1864 GN            Terciaria                  1575696

# %%
df_pivoted2= df_pivoted2.reset_index()
df_pivoted2.head(5)
# Out:
#    VERSION  ID_UPR ID_TECNOLOGIA    ID_CONCEPTO_CTRL     VALOR
# 0   201701  UPR115            NC           Bilateral  81778497
# 1   201701  UPR115            NC        CANON_NC_EST  -2543929
# 2   201701  UPR115            NC   COSTE_COMBUSTIBLE  -1875378
# 3   201701  UPR115            NC  D. Medida Contador     -7853
# 4   201701  UPR115            NC      IMPUESTO ELECT  -3190970

# %%
df_pivoted2.columns
# Out:
# Index(['VERSION', 'ID_UPR', 'ID_TECNOLOGIA', 'ID_CONCEPTO_CTRL', 'VALOR'], dtype='object')

# %%
df_pivoted3 = df_pivoted2.pivot_table( 
                          values=['VALOR'], 
                          index=['VERSION', 'ID_UPR', 'ID_TECNOLOGIA'],
                          columns=['ID_CONCEPTO_CTRL'], 
                          aggfunc=np.sum)
df_pivoted3.sample(10)
# Out:
#                                        VALOR                          \
# ID_CONCEPTO_CTRL              A. No Cobrados AMONIACO ATR     Ajuste
# VERSION ID_UPR  ID_TECNOLOGIA
# 201812  UPR77   NC                       NaN      NaN NaN        NaN
# 201803  UPR1207 EB                       NaN      NaN NaN -3159417.0
# 201702  UPR2415 BP                       NaN      NaN NaN -3508085.0
# 201808  UPR2414 BP                       NaN      NaN NaN        NaN
#         UPR304  HN                       NaN      NaN NaN -3786943.0
# 201805  UPR726  BX                       NaN      NaN NaN        NaN
# 201711  UPR194  HN                       NaN      NaN NaN        NaN
# 201806  UPR115  NC                       NaN      NaN NaN        NaN
# 201707  UPR2103 EB                       NaN      NaN NaN -9265889.0
# 201809  UPR74   HN                       NaN      NaN NaN        NaN
#
#                                                                          \
# ID_CONCEPTO_CTRL              BONO_SOCIAL_PEGO      Banda     Bilateral
# VERSION ID_UPR  ID_TECNOLOGIA
# 201812  UPR77   NC                         NaN        NaN  5.317098e+08
# 201803  UPR1207 EB                         NaN        NaN  3.318776e+06
# 201702  UPR2415 BP                         NaN    18842.0           NaN
# 201808  UPR2414 BP                         NaN        NaN           NaN
#         UPR304  HN                         NaN  3237551.0  2.933524e+07
# 201805  UPR726  BX                         NaN        NaN           NaN
# 201711  UPR194  HN                         NaN  3101623.0  3.746790e+07
# 201806  UPR115  NC                         NaN        NaN  1.509465e+09
# 201707  UPR2103 EB                         NaN        NaN  2.975197e+07
# 201809  UPR74   HN                         NaN        NaN           NaN
#
#                                                                   ...  \
# ID_CONCEPTO_CTRL               CALIZAS CANON HID CANON_CONCESION  ...
# VERSION ID_UPR  ID_TECNOLOGIA                                     ...
# 201812  UPR77   NC                 NaN       NaN             NaN  ...
# 201803  UPR1207 EB                 NaN  -38098.0        -95544.0  ...
# 201702  UPR2415 BP                 NaN       NaN             NaN  ...
# 201808  UPR2414 BP                 NaN       NaN             NaN  ...
#         UPR304  HN            -73120.0       NaN             NaN  ...
# 201805  UPR726  BX                 NaN       0.0             NaN  ...
# 201711  UPR194  HN            -44660.0       NaN             NaN  ...
# 201806  UPR115  NC                 NaN       NaN             NaN  ...
# 201707  UPR2103 EB                 NaN -279300.0             NaN  ...
# 201809  UPR74   HN                 NaN       NaN             NaN  ...
#
#                                                                              \
# ID_CONCEPTO_CTRL              Redespachos Res. Pot. Adicional S. Regulacion
# VERSION ID_UPR  ID_TECNOLOGIA
# 201812  UPR77   NC                    NaN                 NaN           NaN
# 201803  UPR1207 EB                    NaN                 NaN           NaN
# 201702  UPR2415 BP                    NaN                 NaN           NaN
# 201808  UPR2414 BP                    NaN                 NaN           NaN
#         UPR304  HN                    NaN           2139507.0           NaN
# 201805  UPR726  BX                    NaN                 NaN           NaN
# 201711  UPR194  HN                    NaN                 NaN           NaN
# 201806  UPR115  NC                    NaN                 NaN           NaN
# 201707  UPR2103 EB                    NaN                 NaN           NaN
# 201809  UPR74   HN                    NaN                 NaN           NaN
#
#                                                                     \
# ID_CONCEPTO_CTRL              S. Res. Pot. Adicional SERV_GEST_RES
# VERSION ID_UPR  ID_TECNOLOGIA
# 201812  UPR77   NC                            -197.0    -1657920.0
# 201803  UPR1207 EB                            -380.0           NaN
# 201702  UPR2415 BP                            -562.0           NaN
# 201808  UPR2414 BP                           -2720.0           NaN
#         UPR304  HN                           -6591.0           NaN
# 201805  UPR726  BX                            -271.0           NaN
# 201711  UPR194  HN                            -883.0           NaN
# 201806  UPR115  NC                           -5170.0    -4955999.0
# 201707  UPR2103 EB                               NaN           NaN
# 201809  UPR74   HN                               NaN           NaN
#
#                                                                          \
# ID_CONCEPTO_CTRL              TASAS_MEDIOAMB TASA_ARAGON Terciaria UREA
# VERSION ID_UPR  ID_TECNOLOGIA
# 201812  UPR77   NC                 -963125.0         NaN    3148.0  NaN
# 201803  UPR1207 EB                  -31206.0         NaN       NaN  NaN
# 201702  UPR2415 BP                       NaN         NaN  372237.0  NaN
# 201808  UPR2414 BP                       NaN         NaN -472486.0  NaN
#         UPR304  HN                  -95941.0         NaN -804428.0  NaN
# 201805  UPR726  BX                       NaN         NaN       NaN  NaN
# 201711  UPR194  HN                   -3460.0         NaN  102273.0  NaN
# 201806  UPR115  NC                       NaN         NaN       NaN  NaN
# 201707  UPR2103 EB                -4211125.0         NaN  687236.0  NaN
# 201809  UPR74   HN                       NaN         NaN       NaN  NaN
#
#
# ID_CONCEPTO_CTRL                   VCF
# VERSION ID_UPR  ID_TECNOLOGIA
# 201812  UPR77   NC                 NaN
# 201803  UPR1207 EB                 NaN
# 201702  UPR2415 BP             -2505.0
# 201808  UPR2414 BP                 NaN
#         UPR304  HN            -29651.0
# 201805  UPR726  BX                 NaN
# 201711  UPR194  HN            -56871.0
# 201806  UPR115  NC                 NaN
# 201707  UPR2103 EB                 NaN
# 201809  UPR74   HN                 NaN
#
# [10 rows x 42 columns]

# %%
df_pivoted3.columns = df_pivoted3.columns.droplevel()
df_modelize= df_pivoted3.reset_index()
df_modelize.head(10)
# Out:
# ID_CONCEPTO_CTRL  VERSION   ID_UPR ID_TECNOLOGIA  A. No Cobrados  AMONIACO  \
# 0                  201701   UPR115            NC             NaN       NaN
# 1                  201701   UPR116            NC             NaN       NaN
# 2                  201701  UPR1198            NC             NaN       NaN
# 3                  201701  UPR1205            EB             NaN       NaN
# 4                  201701  UPR1206            BX             NaN       NaN
# 5                  201701  UPR1207            EB             NaN       NaN
# 6                  201701  UPR1314            BP             NaN       NaN
# 7                  201701  UPR1315            BP             NaN       NaN
# 8                  201701   UPR160            GN       -994654.0       NaN
# 9                  201701   UPR162            GN       -418200.0       NaN
#
# ID_CONCEPTO_CTRL       ATR    Ajuste  BONO_SOCIAL_PEGO      Banda   Bilateral  \
# 0                      NaN       NaN               NaN        NaN  81778497.0
# 1                      NaN       NaN               NaN        NaN  68455391.0
# 2                      NaN       NaN               NaN        NaN         NaN
# 3                      NaN -124366.0               NaN        NaN   1578792.0
# 4                      NaN   -9972.0               NaN        NaN         NaN
# 5                      NaN -198314.0               NaN    15066.0     59653.0
# 6                      NaN -429377.0               NaN        NaN   -118383.0
# 7                      NaN -506708.0               NaN     2001.0         NaN
# 8                -938689.0       NaN               NaN  1045907.0         NaN
# 9                -507356.0       NaN               NaN   957825.0         NaN
#
# ID_CONCEPTO_CTRL  ...  Redespachos  Res. Pot. Adicional  S. Regulacion  \
# 0                 ...          NaN                  NaN            NaN
# 1                 ...          NaN                  NaN            NaN
# 2                 ...          NaN                  NaN            NaN
# 3                 ...          NaN                  NaN            NaN
# 4                 ...          NaN                  NaN            NaN
# 5                 ...          NaN                  NaN            NaN
# 6                 ...      -8556.0                  NaN            NaN
# 7                 ...       1146.0                  NaN            NaN
# 8                 ...      47854.0              51355.0            NaN
# 9                 ...     745956.0             579221.0            NaN
#
# ID_CONCEPTO_CTRL  S. Res. Pot. Adicional  SERV_GEST_RES  TASAS_MEDIOAMB  \
# 0                                  -36.0     -5156083.0             NaN
# 1                                    NaN     -4357224.0             NaN
# 2                                 -192.0            NaN             NaN
# 3                                 -455.0            NaN        -33711.0
# 4                                   -7.0            NaN        -16346.0
# 5                                 -807.0            NaN         -1528.0
# 6                                  -39.0            NaN             NaN
# 7                                 -397.0            NaN             NaN
# 8                                -2223.0            NaN             NaN
# 9                                 -316.0            NaN             NaN
#
# ID_CONCEPTO_CTRL  TASA_ARAGON  Terciaria  UREA      VCF
# 0                         NaN        NaN   NaN      NaN
# 1                         NaN        NaN   NaN      NaN
# 2                         NaN        NaN   NaN      NaN
# 3                         NaN    55144.0   NaN      NaN
# 4                         NaN        NaN   NaN      NaN
# 5                         NaN   225821.0   NaN    999.0
# 6                         NaN   -24031.0   NaN      NaN
# 7                         NaN   441646.0   NaN   -162.0
# 8                         NaN   251416.0   NaN -14892.0
# 9                         NaN   573346.0   NaN -17674.0
#
# [10 rows x 45 columns]

# %% [markdown]
# Finally, we incorporate now the last column of data that we are gonna implement to the model, the power column from the second
# dataframe that we got in the liquidations R process

# %%
df_power = pd.read_csv(Path.cwd() / 'Outputs' / 'LIQUIDACIONES_MWH.csv' , sep = ';', header = 0 , encoding = "ISO-8859-1",decimal=',')
print(df_power.describe())
df_power.sample(5)
# Out:
#              VERSION         VALOR
# count   13048.000000  1.304800e+04
# mean   201754.106913  4.498754e+05
# std        49.951242  2.031215e+06
# min    201701.000000 -5.489374e+06
# 25%    201706.000000 -9.301933e+03
# 50%    201712.000000  2.225860e+03
# 75%    201806.000000  8.903905e+04
# max    201812.000000  3.518217e+07
#       VERSION   ID_UPR ID_GRUPO_EMPRESARIAL ID_TECNOLOGIA    ID_CONCEPTO_CTRL  \
# 4825   201709  UPR2342             EMPRESA1            LN           Terciaria
# 6074   201711   UPR316             EMPRESA3            GN          G. Desvios
# 1442   201703  UPR2133             EMPRESA2            EB  D. Medida Contador
# 8503   201804  UPR1315             EMPRESA1            BP          G. Desvios
# 8322   201803  UPR2588             EMPRESA3            EB     M. Intradiarios
#
#      ID_UNIDAD      VALOR
# 4825       MWH  -13291.90
# 6074       MWH   33456.50
# 1442       MWH  -52178.46
# 8503       MWH   15903.70
# 8322       MWH  319965.60

# %% [markdown]
# I apply the same filters that I did in the previous dfs
#
# And eventually a group by just in case we have the same problem than before

# %%
df_power = df_power[df_power['ID_GRUPO_EMPRESARIAL'] == 'EMPRESA1']
print(df_power.describe())
# Out:
#              VERSION         VALOR
# count    6417.000000  6.417000e+03
# mean   201755.352189  4.508979e+05
# std        50.180305  2.115280e+06
# min    201701.000000 -3.789073e+06
# 25%    201706.000000 -1.387000e+04
# 50%    201712.000000  2.163250e+02
# 75%    201807.000000  5.869300e+04
# max    201812.000000  3.256008e+07

# %%
df_power = df_power[['VERSION','ID_UPR','ID_TECNOLOGIA','VALOR']]
df_power= df_power.groupby(['VERSION','ID_UPR','ID_TECNOLOGIA']).sum().reset_index()
print(df_power.describe())
# Out:
#              VERSION         VALOR
# count    1024.000000  1.024000e+03
# mean   201755.424805  2.825598e+06
# std        50.143803  4.930549e+06
# min    201701.000000 -3.789073e+06
# 25%    201706.000000  2.363667e+04
# 50%    201712.000000  5.563538e+05
# 75%    201806.000000  3.699485e+06
# max    201812.000000  3.262049e+07

# %%
df_power.describe()
# Out:
#              VERSION         VALOR
# count    1024.000000  1.024000e+03
# mean   201755.424805  2.825598e+06
# std        50.143803  4.930549e+06
# min    201701.000000 -3.789073e+06
# 25%    201706.000000  2.363667e+04
# 50%    201712.000000  5.563538e+05
# 75%    201806.000000  3.699485e+06
# max    201812.000000  3.262049e+07

# %%
df_modelize = pd.merge(df_modelize, df_power, on=['VERSION','ID_UPR','ID_TECNOLOGIA'], how='left')
df_modelize = df_modelize.rename(columns={'VALOR': 'POWER_MWH'})
df_modelize.sample(10)
# Out:
#       VERSION   ID_UPR ID_TECNOLOGIA  A. No Cobrados  AMONIACO        ATR  \
# 6      201701  UPR1314            BP             NaN       NaN        NaN
# 1005   201812  UPR1315            BP             NaN       NaN        NaN
# 210    201705  UPR2622            NC             NaN       NaN        NaN
# 267    201707  UPR1205            EB             NaN       NaN        NaN
# 953    201810    UPR74            HN             NaN       NaN        NaN
# 821    201807   UPR304            HN             NaN       NaN        NaN
# 133    201704   UPR116            NC             NaN       NaN        NaN
# 626    201803  UPR1851            GN             NaN       NaN -3383349.0
# 134    201704  UPR1198            NC             NaN       NaN        NaN
# 645    201803  UPR2622            NC             NaN       NaN        NaN
#
#          Ajuste  BONO_SOCIAL_PEGO     Banda    Bilateral  ...  \
# 6     -429377.0               NaN       NaN    -118383.0  ...
# 1005 -7924166.0               NaN   72267.0          NaN  ...
# 210         NaN               NaN       NaN  241252566.0  ...
# 267   -153932.0               NaN       NaN   34699165.0  ...
# 953         NaN               NaN       NaN          NaN  ...
# 821         NaN               NaN  145485.0   16952863.0  ...
# 133         NaN               NaN       NaN  194407935.0  ...
# 626         NaN         -312679.0       NaN          NaN  ...
# 134         NaN               NaN       NaN          NaN  ...
# 645         NaN               NaN       NaN   53314447.0  ...
#
#       Res. Pot. Adicional  S. Regulacion  S. Res. Pot. Adicional  \
# 6                     NaN            NaN                   -39.0
# 1005                  NaN            NaN                 -3818.0
# 210                   NaN            NaN                     NaN
# 267                   NaN            NaN                     NaN
# 953                   NaN            NaN                     NaN
# 821                   NaN            NaN                 -4176.0
# 133                   NaN            NaN                     NaN
# 626                   NaN            NaN                     NaN
# 134                   NaN            NaN                     NaN
# 645                   NaN            NaN                -10450.0
#
#       SERV_GEST_RES  TASAS_MEDIOAMB  TASA_ARAGON  Terciaria  UREA     VCF  \
# 6               NaN             NaN          NaN   -24031.0   NaN     NaN
# 1005            NaN             NaN          NaN   449460.0   NaN  3849.0
# 210      -3815873.0             NaN          NaN        NaN   NaN     NaN
# 267             NaN       -278650.0          NaN    92364.0   NaN     NaN
# 953             NaN             NaN          NaN        NaN   NaN     NaN
# 821             NaN         95941.0          NaN   127715.0   NaN  3382.0
# 133      -4205449.0             NaN          NaN        NaN   NaN     NaN
# 626             NaN             NaN          NaN        NaN   NaN     NaN
# 134             NaN             NaN          NaN        NaN   NaN     NaN
# 645       -199748.0             NaN          NaN        NaN   NaN     NaN
#
#         POWER_MWH
# 6      -13631.195
# 1005    28134.576
# 210   5103668.888
# 267    758627.698
# 953           NaN
# 821    417225.220
# 133   4473415.595
# 626           NaN
# 134     -5533.966
# 645    624312.820
#
# [10 rows x 46 columns]

# %% [markdown]
# And eventually, let's save all this transformation into a new file. We will use this file as well as the other one previously
# mentioned for the visualization section.
#
# This one will have new challenges such as the NaN replacement, the creation of a new column called Integral_costs and so on...

# %%
df_modelize.to_csv(Path.cwd() / 'Outputs' / 'DF_MODELIZE.csv', sep= ';',decimal=',',index=False)
